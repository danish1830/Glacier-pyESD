# %%
# importing packages

import os 
import pandas as pd
import numpy as np
np.int= int
import xarray as xr
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import KFold
from sklearn.linear_model import RidgeCV

from pyESD.ESD_utils import store_pickle, Dataset
from pyESD.Weatherstation import read_station_csv
from pyESD.standardizer import MonthlyStandardizer
from pyESD.teleconnections import NAO, eof_analysis
from pyESD.metrics import Evaluate
from pyESD.models import Regressors
from pyESD.standardizer import YearlyStandardizer

# %%
t2m_file  = r"C:\Users\danis\Desktop\Danish\ERA5 Data\t2m.nc"
msl_file  = r"C:\Users\danis\Desktop\Danish\ERA5 Data\msl.nc"
tp_file   = r"C:\Users\danis\Desktop\Danish\ERA5 Data\tp.nc"
v10_file  = r"C:\Users\danis\Desktop\Danish\ERA5 Data\v10.nc"
u10_file  = r"C:\Users\danis\Desktop\Danish\ERA5 Data\u10.nc"
ssrd_file = r"C:\Users\danis\Desktop\Danish\ERA5 Data\ssrd.nc"

predictor_dir = os.path.dirname(t2m_file)

# %%
cachedir = r"C:\Users\danis\Desktop\Danish\ERA5 Data\PYESD_CACHE"
os.makedirs(cachedir, exist_ok=True)

# %%
variable= ['Ba']

# time splits
train_range        = pd.date_range("1950-01-01", "2010-01-01", freq="YS")
test_range         = pd.date_range("2011-01-01", "2023-01-01", freq="YS")
complete_range     = pd.date_range("1950-01-01", "2023-01-01", freq="YS")

# pre2k_complete      = pd.date_range("1950-01-01", "2000-01-01", freq="YS")
# pre2k_train_range   = pd.date_range("1950-01-01", "1985-01-01", freq="YS")
# pre2k_test_range    = pd.date_range("1986-01-01", "2000-01-01", freq="YS")

# post2k_complete     = pd.date_range("2000-01-01", "2023-01-01", freq="YS")
# post2k_train_range  = pd.date_range("2000-01-01", "2012-01-01", freq="YS")
# post2k_test_range   = pd.date_range("2013-01-01", "2023-01-01", freq="YS")

predictors=["t2m", "tp", "u10", "v10", "ssrd", "NAO", "EA"]

# %%
ERA5Data = Dataset(name="ERA5", variables={"t2m": t2m_file,
                                           "msl": msl_file, 
                                           "tp": tp_file,
                                           "u10": u10_file,
                                           "v10": v10_file,
                                           "ssrd": ssrd_file}, domain_name="NH")                                

ERA5Data

# %%
glaciernames = ['Alfotbreen', 'Austdalsbreen', 'Engabreen', 'Grafjellsbrea', 'Grasubreen', 
                             'Hansebreen', 'Hellstugubreen', 'Langfjordjokelen', 'Nigardsbreen', 'Rembesdalskaka', 'Storbreen']


## Creating short form dictinary for glacier names

glacier_shortnames = {'Alfotbreen': 'Alf', 
                        'Austdalsbreen': 'Aus', 
                        'Engabreen': 'Eng', 
                        'Grafjellsbrea': 'Graf', 
                        'Grasubreen': 'Gras', 
                        'Hansebreen': 'Han', 
                        'Hellstugubreen': 'Hell', 
                        'Langfjordjokelen': 'Lan',
                        'Nigardsbreen': 'Nig', 
                        'Rembesdalskaka': 'Rem', 
                        'Storbreen': 'Sto'}

glacier_datadir= r"C:\Users\danis\Desktop\Danish\NVE\glaciers\Mass Balance\Cleaned"
glaciers = {}

# %%
regressors= ['RidgeCV', 'Bagging', 'ARD', 'RandomForest', 'XGBoost', 'BayesianRidge']

regressor_shortnames = {
    "RandomForest": "RF",
    "ARD": "ARD",
    "RidgeCV": "Ridge",
    "XGBoost": "XGB",
    "Bagging": "Bag",
    "BayesianRidge": "BYR"

}
selector_shortnames = {
    "Recursive": "Rec",
    "Sequential": "Seq",
    "TreeBased": "Tree"
}

# %%
results = []
results_dir = r"C:\Users\danis\Desktop\Danish\Thesis Model Results"

# %%
for variable in ['Ba']:
    print(f"\n===== Running model for variable: {variable} =====")
    
    for name in glacier_shortnames:
        print(f"\n--- Processing Station: {name} ---")

        for regressor in regressors:
            print (f"\n--- Running Regressor: {regressor} ===")

            glacier_file = os.path.join(glacier_datadir, f"{name}_cleaned.csv")
            GO = read_station_csv(filename=glacier_file, varname=variable) 
            glaciers[name] = GO

            available_train_range = [d for d in train_range if d in GO.get_var(variable, None).index]
            available_test_range  = [d for d in test_range if d in GO.get_var(variable, None).index]

            # 1. defining model predictors
            GO.set_predictors(variable=variable, predictors= predictors, 
                              cachedir=cachedir)

            y = GO.get_var(variable, available_train_range)
            print(f"{variable} @ {name}: Missing months:", y.isna().sum())
            if y.dropna().shape[0] < 12:
                print(f"⚠️ Skipping {name} — insufficient glacier data")
                continue

            # 2. setting standardardizer
            GO.set_standardizer(variable, standardizer= YearlyStandardizer(detrending=True, scaling=True))
    
            # 3. defining scoring metrics
            scoring= ['neg_root_mean_squared_error', 'r2', 'neg_mean_absolute_error']
    
             # 4. training model
            GO.set_model(variable=variable,
                         method= regressor,
                         predictor_dataset=ERA5Data,
                         daterange=available_train_range,
                         scoring= scoring,
                         cv=KFold(n_splits=10))
    
            # 5. setting selectors
            for selector_method in ['Recursive', 'Sequential', 'TreeBased']:
                print(f"     -> Selector method: {selector_method}")
    
                if selector_method == 'Recursive':
                    GO.fit(variable, available_train_range, ERA5Data, fit_predictors=True,
                           predictor_selector=True, selector_method=selector_method,
                           selector_regressor= 'ARD', cal_relative_importance=False)
                    
                elif selector_method == 'TreeBased':
                    GO.fit(variable, available_train_range, ERA5Data, fit_predictors=True,
                           predictor_selector=True, selector_method=selector_method,
                           selector_regressor='ExtraTree')
    
                elif selector_method == 'Sequential':
                    GO.fit(variable, available_train_range, ERA5Data, fit_predictors=True,
                           predictor_selector=True, selector_method=selector_method,
                           select_regressor= 'ARD', num_predictors= 2, selector_direction='forward')
    
                else:
                    raise ValueError('Selector method not recognized')
    
                
                selected_predictors = GO.selected_names(variable)
                ypred = GO.predict(variable, available_test_range, ERA5Data)
    
                # 6. cross validate and predict for training period
                #score_1950to2010, ypred_1950to2010 = GO.cross_validate_and_predict(variable, available_train_range, ERA5Data)
                score_train, ypred_train= GO.cross_validate_and_predict(variable, available_train_range, ERA5Data)

                # 7. prediction for training period
                #ypred_1950to2010 = GO.predict(variable, available_train_range, ERA5Data)
                ypred_train = GO.predict(variable, available_train_range, ERA5Data)

                # 8. prediction for testing period
                #ypred_2011to2022 = GO.predict(variable, available_test_range , ERA5Data)
                ypred_test = GO.predict(variable, available_test_range, ERA5Data)
          
                # 9. Evaluate metrics using test predictions
                y_true_test = GO.get_var(variable, available_test_range)
                evaluator = Evaluate(y_true_test, ypred_test)
                r2 = evaluator.R2_score()
                rmse = evaluator.RMSE()
                mae = evaluator.MAE()
                            
                # 10. Save results
                # results.append({
                #     "Variable": variable,
                #     "Glacier": glacier_shortnames[name],
                #     "Regressor": regressor_shortnames[regressor],
                #     "Selector": selector_shortnames[selector_method],
                #     "Predictors": selected_predictors,
                #     "R2": r2,
                #     "RMSE": rmse,
                #     "MAE": mae
                # })

                # Saving results in a structured format for thesis
                results.append({
                    "Glacier": glacier_shortnames[name],
                    "Model_Combination": f"{regressor_shortnames[regressor]} + {selector_shortnames[selector_method]}",
                    "Model_Type": "Linear" if regressor_shortnames[regressor] in ["RidgeCV", "ARD", "BayesianRidge"] else "Non-linear",
                    "R2": round(r2, 3),
                    "RMSE": round(rmse, 3)
                })

    
                df_preds = pd.DataFrame({
                    "Date": GO.get_var(variable, available_train_range).index,
                    "Observed": GO.get_var(variable, available_train_range).values,
                    "Predicted": ypred_train
                })
    
                #filename = os.path.join(results_dir, f"predictions_{name}_{regressor}_{selector_method}.csv")
                #df_preds.to_csv(filename, index=False)
    
                print(f"Done with {regressor} for {name} using {selector_method}. Selected predictors: {selected_predictors}")

results_df= pd.DataFrame(results)
# Out:
# ===== Running model for variable: Ba =====
#
# --- Processing Station: Alfotbreen ---
#
# --- Running Regressor: RidgeCV ===
# Alfotbreen 61.75 5.65 1180.0
# Ba @ Alfotbreen: Missing months: 0
#      -> Selector method: Recursive
# 7 : optimal number of predictors and selected variables are Index(['t2m', 'tp', 'u10', 'v10', 'ssrd', 'NAO', 'EA'], dtype='object')
# R² (Coefficient of determinaiton): 0.65
# RMSE: 0.495510
# Mean Absolute Error): 0.43
# Done with RidgeCV for Alfotbreen using Recursive. Selected predictors:    t2m  tp  u10  v10  ssrd  NAO  EA
# 0  t2m  tp  u10  v10  ssrd  NAO  EA
#      -> Selector method: Sequential
# 2 : optimal number of predictors and selected variables are Index(['u10', 'NAO'], dtype='object')
# R² (Coefficient of determinaiton): 0.60
# RMSE: 0.532003
# Mean Absolute Error): 0.46
# Done with RidgeCV for Alfotbreen using Sequential. Selected predictors:    u10  NAO
# 0  u10  NAO
#      -> Selector method: TreeBased
# 2 : optimal number of predictors and selected variables are Index(['tp', 'u10'], dtype='object')
# R² (Coefficient of determinaiton): 0.57
# RMSE: 0.551929
# Mean Absolute Error): 0.47
# Done with RidgeCV for Alfotbreen using TreeBased. Selected predictors:    tp  u10
# 0  tp  u10
#
# --- Running Regressor: Bagging ===
# Alfotbreen 61.75 5.65 1180.0
# Ba @ Alfotbreen: Missing months: 0
#      -> Selector method: Recursive
# 7 : optimal number of predictors and selected variables are Index(['t2m', 'tp', 'u10', 'v10', 'ssrd', 'NAO', 'EA'], dtype='object')
# R² (Coefficient of determinaiton): 0.47
# RMSE: 0.613082
# Mean Absolute Error): 0.52
# Done with Bagging for Alfotbreen using Recursive. Selected predictors:    t2m  tp  u10  v10  ssrd  NAO  EA
# 0  t2m  tp  u10  v10  ssrd  NAO  EA
#      -> Selector method: Sequential
# 2 : optimal number of predictors and selected variables are Index(['u10', 'NAO'], dtype='object')
# R² (Coefficient of determinaiton): 0.41
# RMSE: 0.645096
# Mean Absolute Error): 0.55
# Done with Bagging for Alfotbreen using Sequential. Selected predictors:    u10  NAO
# 0  u10  NAO
#      -> Selector method: TreeBased
# 2 : optimal number of predictors and selected variables are Index(['tp', 'u10'], dtype='object')
# R² (Coefficient of determinaiton): 0.56
# RMSE: 0.555666
# Mean Absolute Error): 0.49
# Done with Bagging for Alfotbreen using TreeBased. Selected predictors:    tp  u10
# 0  tp  u10
#
# --- Running Regressor: ARD ===
# Alfotbreen 61.75 5.65 1180.0
# Ba @ Alfotbreen: Missing months: 0
#      -> Selector method: Recursive
# 7 : optimal number of predictors and selected variables are Index(['t2m', 'tp', 'u10', 'v10', 'ssrd', 'NAO', 'EA'], dtype='object')
# R² (Coefficient of determinaiton): 0.66
# RMSE: 0.489479
# Mean Absolute Error): 0.41
# Done with ARD for Alfotbreen using Recursive. Selected predictors:    t2m  tp  u10  v10  ssrd  NAO  EA
# 0  t2m  tp  u10  v10  ssrd  NAO  EA
#      -> Selector method: Sequential
# 2 : optimal number of predictors and selected variables are Index(['u10', 'NAO'], dtype='object')
# R² (Coefficient of determinaiton): 0.60
# RMSE: 0.533670
# Mean Absolute Error): 0.47
# Done with ARD for Alfotbreen using Sequential. Selected predictors:    u10  NAO
# 0  u10  NAO
#      -> Selector method: TreeBased
# 2 : optimal number of predictors and selected variables are Index(['tp', 'u10'], dtype='object')
# R² (Coefficient of determinaiton): 0.58
# RMSE: 0.543092
# Mean Absolute Error): 0.47
# Done with ARD for Alfotbreen using TreeBased. Selected predictors:    tp  u10
# 0  tp  u10
#
# --- Running Regressor: RandomForest ===
# Alfotbreen 61.75 5.65 1180.0
# Ba @ Alfotbreen: Missing months: 0
#      -> Selector method: Recursive
# 7 : optimal number of predictors and selected variables are Index(['t2m', 'tp', 'u10', 'v10', 'ssrd', 'NAO', 'EA'], dtype='object')
# R² (Coefficient of determinaiton): 0.45
# RMSE: 0.621589
# Mean Absolute Error): 0.52
# Done with RandomForest for Alfotbreen using Recursive. Selected predictors:    t2m  tp  u10  v10  ssrd  NAO  EA
# 0  t2m  tp  u10  v10  ssrd  NAO  EA
#      -> Selector method: Sequential
# 2 : optimal number of predictors and selected variables are Index(['u10', 'NAO'], dtype='object')
# R² (Coefficient of determinaiton): 0.43
# RMSE: 0.636489
# Mean Absolute Error): 0.54
# Done with RandomForest for Alfotbreen using Sequential. Selected predictors:    u10  NAO
# 0  u10  NAO
#      -> Selector method: TreeBased
# 2 : optimal number of predictors and selected variables are Index(['tp', 'u10'], dtype='object')
# R² (Coefficient of determinaiton): 0.53
# RMSE: 0.580078
# Mean Absolute Error): 0.51
# Done with RandomForest for Alfotbreen using TreeBased. Selected predictors:    tp  u10
# 0  tp  u10
#
# --- Running Regressor: XGBoost ===
# Alfotbreen 61.75 5.65 1180.0
# Ba @ Alfotbreen: Missing months: 0
#      -> Selector method: Recursive
# 7 : optimal number of predictors and selected variables are Index(['t2m', 'tp', 'u10', 'v10', 'ssrd', 'NAO', 'EA'], dtype='object')
# R² (Coefficient of determinaiton): 0.26
# RMSE: 0.726131
# Mean Absolute Error): 0.61
# Done with XGBoost for Alfotbreen using Recursive. Selected predictors:    t2m  tp  u10  v10  ssrd  NAO  EA
# 0  t2m  tp  u10  v10  ssrd  NAO  EA
#      -> Selector method: Sequential
# 2 : optimal number of predictors and selected variables are Index(['u10', 'NAO'], dtype='object')
# R² (Coefficient of determinaiton): -0.01
# RMSE: 0.847107
# Mean Absolute Error): 0.67
# Done with XGBoost for Alfotbreen using Sequential. Selected predictors:    u10  NAO
# 0  u10  NAO
#      -> Selector method: TreeBased
# 2 : optimal number of predictors and selected variables are Index(['tp', 'u10'], dtype='object')
# R² (Coefficient of determinaiton): 0.35
# RMSE: 0.679286
# Mean Absolute Error): 0.59
# Done with XGBoost for Alfotbreen using TreeBased. Selected predictors:    tp  u10
# 0  tp  u10
#
# --- Running Regressor: BayesianRidge ===
# Alfotbreen 61.75 5.65 1180.0
# Ba @ Alfotbreen: Missing months: 0
#      -> Selector method: Recursive
# 7 : optimal number of predictors and selected variables are Index(['t2m', 'tp', 'u10', 'v10', 'ssrd', 'NAO', 'EA'], dtype='object')
# R² (Coefficient of determinaiton): 0.65
# RMSE: 0.497602
# Mean Absolute Error): 0.43
# Done with BayesianRidge for Alfotbreen using Recursive. Selected predictors:    t2m  tp  u10  v10  ssrd  NAO  EA
# 0  t2m  tp  u10  v10  ssrd  NAO  EA
#      -> Selector method: Sequential
# 2 : optimal number of predictors and selected variables are Index(['u10', 'NAO'], dtype='object')
# R² (Coefficient of determinaiton): 0.60
# RMSE: 0.531552
# Mean Absolute Error): 0.47
# Done with BayesianRidge for Alfotbreen using Sequential. Selected predictors:    u10  NAO
# 0  u10  NAO
#      -> Selector method: TreeBased
# 2 : optimal number of predictors and selected variables are Index(['tp', 'u10'], dtype='object')
# R² (Coefficient of determinaiton): 0.57
# RMSE: 0.550419
# Mean Absolute Error): 0.49
# Done with BayesianRidge for Alfotbreen using TreeBased. Selected predictors:    tp  u10
# 0  tp  u10
#
# --- Processing Station: Austdalsbreen ---
#
# --- Running Regressor: RidgeCV ===
# Austdalsbreen 61.75 7.33 1470.0
# Ba @ Austdalsbreen: Missing months: 0
#      -> Selector method: Recursive
# 7 : optimal number of predictors and selected variables are Index(['t2m', 'tp', 'u10', 'v10', 'ssrd', 'NAO', 'EA'], dtype='object')
# R² (Coefficient of determinaiton): 0.52
# RMSE: 0.645394
# Mean Absolute Error): 0.53
# Done with RidgeCV for Austdalsbreen using Recursive. Selected predictors:    t2m  tp  u10  v10  ssrd  NAO  EA
# 0  t2m  tp  u10  v10  ssrd  NAO  EA
#      -> Selector method: Sequential
# 2 : optimal number of predictors and selected variables are Index(['v10', 'NAO'], dtype='object')
# R² (Coefficient of determinaiton): 0.32
# RMSE: 0.767845
# Mean Absolute Error): 0.64
# Done with RidgeCV for Austdalsbreen using Sequential. Selected predictors:    v10  NAO
# 0  v10  NAO
#      -> Selector method: TreeBased
# 3 : optimal number of predictors and selected variables are Index(['tp', 'u10', 'v10'], dtype='object')
# R² (Coefficient of determinaiton): 0.69
# RMSE: 0.523944
# Mean Absolute Error): 0.44
# Done with RidgeCV for Austdalsbreen using TreeBased. Selected predictors:    tp  u10  v10
# 0  tp  u10  v10
#
# --- Running Regressor: Bagging ===
# Austdalsbreen 61.75 7.33 1470.0
# Ba @ Austdalsbreen: Missing months: 0
#      -> Selector method: Recursive
# 7 : optimal number of predictors and selected variables are Index(['t2m', 'tp', 'u10', 'v10', 'ssrd', 'NAO', 'EA'], dtype='object')
# R² (Coefficient of determinaiton): 0.71
# RMSE: 0.507181
# Mean Absolute Error): 0.43
# Done with Bagging for Austdalsbreen using Recursive. Selected predictors:    t2m  tp  u10  v10  ssrd  NAO  EA
# 0  t2m  tp  u10  v10  ssrd  NAO  EA
#      -> Selector method: Sequential
# 2 : optimal number of predictors and selected variables are Index(['v10', 'NAO'], dtype='object')
# R² (Coefficient of determinaiton): 0.38
# RMSE: 0.735036
# Mean Absolute Error): 0.66
# Done with Bagging for Austdalsbreen using Sequential. Selected predictors:    v10  NAO
# 0  v10  NAO
#      -> Selector method: TreeBased
# 2 : optimal number of predictors and selected variables are Index(['tp', 'v10'], dtype='object')
# R² (Coefficient of determinaiton): 0.65
# RMSE: 0.554580
# Mean Absolute Error): 0.51
# Done with Bagging for Austdalsbreen using TreeBased. Selected predictors:    tp  v10
# 0  tp  v10
#
# --- Running Regressor: ARD ===
# Austdalsbreen 61.75 7.33 1470.0
# Ba @ Austdalsbreen: Missing months: 0
#      -> Selector method: Recursive
# 7 : optimal number of predictors and selected variables are Index(['t2m', 'tp', 'u10', 'v10', 'ssrd', 'NAO', 'EA'], dtype='object')
# R² (Coefficient of determinaiton): 0.44
# RMSE: 0.698216
# Mean Absolute Error): 0.59
# Done with ARD for Austdalsbreen using Recursive. Selected predictors:    t2m  tp  u10  v10  ssrd  NAO  EA
# 0  t2m  tp  u10  v10  ssrd  NAO  EA
#      -> Selector method: Sequential
# 2 : optimal number of predictors and selected variables are Index(['v10', 'NAO'], dtype='object')
# R² (Coefficient of determinaiton): 0.15
# RMSE: 0.860862
# Mean Absolute Error): 0.70
# Done with ARD for Austdalsbreen using Sequential. Selected predictors:    v10  NAO
# 0  v10  NAO
#      -> Selector method: TreeBased
# 2 : optimal number of predictors and selected variables are Index(['tp', 'v10'], dtype='object')
# R² (Coefficient of determinaiton): 0.65
# RMSE: 0.551263
# Mean Absolute Error): 0.48
# Done with ARD for Austdalsbreen using TreeBased. Selected predictors:    tp  v10
# 0  tp  v10
#
# --- Running Regressor: RandomForest ===
# Austdalsbreen 61.75 7.33 1470.0
# Ba @ Austdalsbreen: Missing months: 0
#      -> Selector method: Recursive
# 7 : optimal number of predictors and selected variables are Index(['t2m', 'tp', 'u10', 'v10', 'ssrd', 'NAO', 'EA'], dtype='object')
# R² (Coefficient of determinaiton): 0.71
# RMSE: 0.504345
# Mean Absolute Error): 0.42
# Done with RandomForest for Austdalsbreen using Recursive. Selected predictors:    t2m  tp  u10  v10  ssrd  NAO  EA
# 0  t2m  tp  u10  v10  ssrd  NAO  EA
#      -> Selector method: Sequential
# 2 : optimal number of predictors and selected variables are Index(['v10', 'NAO'], dtype='object')
# R² (Coefficient of determinaiton): 0.37
# RMSE: 0.741661
# Mean Absolute Error): 0.67
# Done with RandomForest for Austdalsbreen using Sequential. Selected predictors:    v10  NAO
# 0  v10  NAO
#      -> Selector method: TreeBased
# 2 : optimal number of predictors and selected variables are Index(['tp', 'v10'], dtype='object')
# R² (Coefficient of determinaiton): 0.64
# RMSE: 0.559050
# Mean Absolute Error): 0.51
# Done with RandomForest for Austdalsbreen using TreeBased. Selected predictors:    tp  v10
# 0  tp  v10
#
# --- Running Regressor: XGBoost ===
# Austdalsbreen 61.75 7.33 1470.0
# Ba @ Austdalsbreen: Missing months: 0
#      -> Selector method: Recursive
# 7 : optimal number of predictors and selected variables are Index(['t2m', 'tp', 'u10', 'v10', 'ssrd', 'NAO', 'EA'], dtype='object')
# R² (Coefficient of determinaiton): 0.75
# RMSE: 0.463569
# Mean Absolute Error): 0.38
# Done with XGBoost for Austdalsbreen using Recursive. Selected predictors:    t2m  tp  u10  v10  ssrd  NAO  EA
# 0  t2m  tp  u10  v10  ssrd  NAO  EA
#      -> Selector method: Sequential
# 2 : optimal number of predictors and selected variables are Index(['v10', 'NAO'], dtype='object')
# R² (Coefficient of determinaiton): -0.23
# RMSE: 1.035053
# Mean Absolute Error): 0.86
# Done with XGBoost for Austdalsbreen using Sequential. Selected predictors:    v10  NAO
# 0  v10  NAO
#      -> Selector method: TreeBased
# 2 : optimal number of predictors and selected variables are Index(['tp', 'v10'], dtype='object')
# R² (Coefficient of determinaiton): 0.50
# RMSE: 0.662738
# Mean Absolute Error): 0.59
# Done with XGBoost for Austdalsbreen using TreeBased. Selected predictors:    tp  v10
# 0  tp  v10
#
# --- Running Regressor: BayesianRidge ===
# Austdalsbreen 61.75 7.33 1470.0
# Ba @ Austdalsbreen: Missing months: 0
#      -> Selector method: Recursive
# 7 : optimal number of predictors and selected variables are Index(['t2m', 'tp', 'u10', 'v10', 'ssrd', 'NAO', 'EA'], dtype='object')
# R² (Coefficient of determinaiton): 0.30
# RMSE: 0.779925
# Mean Absolute Error): 0.61
# Done with BayesianRidge for Austdalsbreen using Recursive. Selected predictors:    t2m  tp  u10  v10  ssrd  NAO  EA
# 0  t2m  tp  u10  v10  ssrd  NAO  EA
#      -> Selector method: Sequential
# 2 : optimal number of predictors and selected variables are Index(['v10', 'NAO'], dtype='object')
# R² (Coefficient of determinaiton): 0.32
# RMSE: 0.772055
# Mean Absolute Error): 0.64
# Done with BayesianRidge for Austdalsbreen using Sequential. Selected predictors:    v10  NAO
# 0  v10  NAO
#      -> Selector method: TreeBased
# 2 : optimal number of predictors and selected variables are Index(['tp', 'v10'], dtype='object')
# R² (Coefficient of determinaiton): 0.15
# RMSE: 0.861620
# Mean Absolute Error): 0.70
# Done with BayesianRidge for Austdalsbreen using TreeBased. Selected predictors:    tp  v10
# 0  tp  v10
#
# --- Processing Station: Engabreen ---
#
# --- Running Regressor: RidgeCV ===
# Engabreen 66.65 13.85 850.0
# Ba @ Engabreen: Missing months: 0
#      -> Selector method: Recursive
# 7 : optimal number of predictors and selected variables are Index(['t2m', 'tp', 'u10', 'v10', 'ssrd', 'NAO', 'EA'], dtype='object')
# R² (Coefficient of determinaiton): 0.47
# RMSE: 0.767463
# Mean Absolute Error): 0.63
# Done with RidgeCV for Engabreen using Recursive. Selected predictors:    t2m  tp  u10  v10  ssrd  NAO  EA
# 0  t2m  tp  u10  v10  ssrd  NAO  EA
#      -> Selector method: Sequential
# 2 : optimal number of predictors and selected variables are Index(['tp', 'u10'], dtype='object')
# R² (Coefficient of determinaiton): 0.44
# RMSE: 0.788852
# Mean Absolute Error): 0.65
# Done with RidgeCV for Engabreen using Sequential. Selected predictors:    tp  u10
# 0  tp  u10
#      -> Selector method: TreeBased
# 2 : optimal number of predictors and selected variables are Index(['tp', 'u10'], dtype='object')
# R² (Coefficient of determinaiton): 0.44
# RMSE: 0.788852
# Mean Absolute Error): 0.65
# Done with RidgeCV for Engabreen using TreeBased. Selected predictors:    tp  u10
# 0  tp  u10
#
# --- Running Regressor: Bagging ===
# Engabreen 66.65 13.85 850.0
# Ba @ Engabreen: Missing months: 0
#      -> Selector method: Recursive
# 7 : optimal number of predictors and selected variables are Index(['t2m', 'tp', 'u10', 'v10', 'ssrd', 'NAO', 'EA'], dtype='object')
# R² (Coefficient of determinaiton): 0.32
# RMSE: 0.872977
# Mean Absolute Error): 0.66
# Done with Bagging for Engabreen using Recursive. Selected predictors:    t2m  tp  u10  v10  ssrd  NAO  EA
# 0  t2m  tp  u10  v10  ssrd  NAO  EA
#      -> Selector method: Sequential
# 2 : optimal number of predictors and selected variables are Index(['tp', 'u10'], dtype='object')
# R² (Coefficient of determinaiton): 0.22
# RMSE: 0.932271
# Mean Absolute Error): 0.71
# Done with Bagging for Engabreen using Sequential. Selected predictors:    tp  u10
# 0  tp  u10
#      -> Selector method: TreeBased
# 2 : optimal number of predictors and selected variables are Index(['tp', 'u10'], dtype='object')
# R² (Coefficient of determinaiton): 0.22
# RMSE: 0.932271
# Mean Absolute Error): 0.71
# Done with Bagging for Engabreen using TreeBased. Selected predictors:    tp  u10
# 0  tp  u10
#
# --- Running Regressor: ARD ===
# Engabreen 66.65 13.85 850.0
# Ba @ Engabreen: Missing months: 0
#      -> Selector method: Recursive
# 7 : optimal number of predictors and selected variables are Index(['t2m', 'tp', 'u10', 'v10', 'ssrd', 'NAO', 'EA'], dtype='object')
# R² (Coefficient of determinaiton): 0.60
# RMSE: 0.672717
# Mean Absolute Error): 0.53
# Done with ARD for Engabreen using Recursive. Selected predictors:    t2m  tp  u10  v10  ssrd  NAO  EA
# 0  t2m  tp  u10  v10  ssrd  NAO  EA
#      -> Selector method: Sequential
# 2 : optimal number of predictors and selected variables are Index(['tp', 'u10'], dtype='object')
# R² (Coefficient of determinaiton): 0.60
# RMSE: 0.672630
# Mean Absolute Error): 0.53
# Done with ARD for Engabreen using Sequential. Selected predictors:    tp  u10
# 0  tp  u10
#      -> Selector method: TreeBased
# 2 : optimal number of predictors and selected variables are Index(['tp', 'u10'], dtype='object')
# R² (Coefficient of determinaiton): 0.60
# RMSE: 0.672630
# Mean Absolute Error): 0.53
# Done with ARD for Engabreen using TreeBased. Selected predictors:    tp  u10
# 0  tp  u10
#
# --- Running Regressor: RandomForest ===
# Engabreen 66.65 13.85 850.0
# Ba @ Engabreen: Missing months: 0
#      -> Selector method: Recursive
# 7 : optimal number of predictors and selected variables are Index(['t2m', 'tp', 'u10', 'v10', 'ssrd', 'NAO', 'EA'], dtype='object')
# R² (Coefficient of determinaiton): 0.34
# RMSE: 0.856111
# Mean Absolute Error): 0.65
# Done with RandomForest for Engabreen using Recursive. Selected predictors:    t2m  tp  u10  v10  ssrd  NAO  EA
# 0  t2m  tp  u10  v10  ssrd  NAO  EA
#      -> Selector method: Sequential
# 2 : optimal number of predictors and selected variables are Index(['tp', 'u10'], dtype='object')
# R² (Coefficient of determinaiton): 0.21
# RMSE: 0.938015
# Mean Absolute Error): 0.71
# Done with RandomForest for Engabreen using Sequential. Selected predictors:    tp  u10
# 0  tp  u10
#      -> Selector method: TreeBased
# 2 : optimal number of predictors and selected variables are Index(['tp', 'u10'], dtype='object')
# R² (Coefficient of determinaiton): 0.21
# RMSE: 0.938015
# Mean Absolute Error): 0.71
# Done with RandomForest for Engabreen using TreeBased. Selected predictors:    tp  u10
# 0  tp  u10
#
# --- Running Regressor: XGBoost ===
# Engabreen 66.65 13.85 850.0
# Ba @ Engabreen: Missing months: 0
#      -> Selector method: Recursive
# 7 : optimal number of predictors and selected variables are Index(['t2m', 'tp', 'u10', 'v10', 'ssrd', 'NAO', 'EA'], dtype='object')
# R² (Coefficient of determinaiton): 0.07
# RMSE: 1.020127
# Mean Absolute Error): 0.83
# Done with XGBoost for Engabreen using Recursive. Selected predictors:    t2m  tp  u10  v10  ssrd  NAO  EA
# 0  t2m  tp  u10  v10  ssrd  NAO  EA
#      -> Selector method: Sequential
# 2 : optimal number of predictors and selected variables are Index(['tp', 'u10'], dtype='object')
# R² (Coefficient of determinaiton): -0.11
# RMSE: 1.115922
# Mean Absolute Error): 0.84
# Done with XGBoost for Engabreen using Sequential. Selected predictors:    tp  u10
# 0  tp  u10
#      -> Selector method: TreeBased
# 3 : optimal number of predictors and selected variables are Index(['t2m', 'tp', 'u10'], dtype='object')
# R² (Coefficient of determinaiton): -0.31
# RMSE: 1.210819
# Mean Absolute Error): 0.96
# Done with XGBoost for Engabreen using TreeBased. Selected predictors:    t2m  tp  u10
# 0  t2m  tp  u10
#
# --- Running Regressor: BayesianRidge ===
# Engabreen 66.65 13.85 850.0
# Ba @ Engabreen: Missing months: 0
#      -> Selector method: Recursive
# 7 : optimal number of predictors and selected variables are Index(['t2m', 'tp', 'u10', 'v10', 'ssrd', 'NAO', 'EA'], dtype='object')
# R² (Coefficient of determinaiton): 0.45
# RMSE: 0.785463
# Mean Absolute Error): 0.66
# Done with BayesianRidge for Engabreen using Recursive. Selected predictors:    t2m  tp  u10  v10  ssrd  NAO  EA
# 0  t2m  tp  u10  v10  ssrd  NAO  EA
#      -> Selector method: Sequential
# 2 : optimal number of predictors and selected variables are Index(['tp', 'u10'], dtype='object')
# R² (Coefficient of determinaiton): 0.49
# RMSE: 0.755929
# Mean Absolute Error): 0.62
# Done with BayesianRidge for Engabreen using Sequential. Selected predictors:    tp  u10
# 0  tp  u10
#      -> Selector method: TreeBased
# 2 : optimal number of predictors and selected variables are Index(['tp', 'u10'], dtype='object')
# R² (Coefficient of determinaiton): 0.49
# RMSE: 0.755929
# Mean Absolute Error): 0.62
# Done with BayesianRidge for Engabreen using TreeBased. Selected predictors:    tp  u10
# 0  tp  u10
#
# --- Processing Station: Grafjellsbrea ---
#
# --- Running Regressor: RidgeCV ===
# Grafjellsbrea 60.1 6.38 1320.0
# Ba @ Grafjellsbrea: Missing months: 0
#      -> Selector method: Recursive
# 6 : optimal number of predictors and selected variables are Index(['t2m', 'tp', 'u10', 'v10', 'ssrd', 'NAO'], dtype='object')
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_search.py:1108: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan]
#   warnings.warn(
# R² (Coefficient of determinaiton): 0.42
# RMSE: 0.877402
# Mean Absolute Error): 0.87
# Done with RidgeCV for Grafjellsbrea using Recursive. Selected predictors:    t2m  tp  u10  v10  ssrd  NAO
# 0  t2m  tp  u10  v10  ssrd  NAO
#      -> Selector method: Sequential
# 2 : optimal number of predictors and selected variables are Index(['ssrd', 'NAO'], dtype='object')
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_search.py:1108: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan]
#   warnings.warn(
# R² (Coefficient of determinaiton): 0.53
# RMSE: 0.791843
# Mean Absolute Error): 0.66
# Done with RidgeCV for Grafjellsbrea using Sequential. Selected predictors:    ssrd  NAO
# 0  ssrd  NAO
#      -> Selector method: TreeBased
# 3 : optimal number of predictors and selected variables are Index(['tp', 'u10', 'ssrd'], dtype='object')
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_search.py:1108: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan]
#   warnings.warn(
# R² (Coefficient of determinaiton): 0.40
# RMSE: 0.895719
# Mean Absolute Error): 0.89
# Done with RidgeCV for Grafjellsbrea using TreeBased. Selected predictors:    tp  u10  ssrd
# 0  tp  u10  ssrd
#
# --- Running Regressor: Bagging ===
# Grafjellsbrea 60.1 6.38 1320.0
# Ba @ Grafjellsbrea: Missing months: 0
#      -> Selector method: Recursive
# 6 : optimal number of predictors and selected variables are Index(['t2m', 'tp', 'u10', 'v10', 'ssrd', 'NAO'], dtype='object')
# R² (Coefficient of determinaiton): 0.23
# RMSE: 1.014047
# Mean Absolute Error): 1.01
# Done with Bagging for Grafjellsbrea using Recursive. Selected predictors:    t2m  tp  u10  v10  ssrd  NAO
# 0  t2m  tp  u10  v10  ssrd  NAO
#      -> Selector method: Sequential
# 2 : optimal number of predictors and selected variables are Index(['ssrd', 'NAO'], dtype='object')
# R² (Coefficient of determinaiton): 0.27
# RMSE: 0.984373
# Mean Absolute Error): 0.95
# Done with Bagging for Grafjellsbrea using Sequential. Selected predictors:    ssrd  NAO
# 0  ssrd  NAO
#      -> Selector method: TreeBased
# 2 : optimal number of predictors and selected variables are Index(['tp', 'ssrd'], dtype='object')
# R² (Coefficient of determinaiton): 0.21
# RMSE: 1.027014
# Mean Absolute Error): 1.02
# Done with Bagging for Grafjellsbrea using TreeBased. Selected predictors:    tp  ssrd
# 0  tp  ssrd
#
# --- Running Regressor: ARD ===
# Grafjellsbrea 60.1 6.38 1320.0
# Ba @ Grafjellsbrea: Missing months: 0
#      -> Selector method: Recursive
# 6 : optimal number of predictors and selected variables are Index(['t2m', 'tp', 'u10', 'v10', 'ssrd', 'NAO'], dtype='object')
# R² (Coefficient of determinaiton): 0.50
# RMSE: 0.819870
# Mean Absolute Error): 0.79
# Done with ARD for Grafjellsbrea using Recursive. Selected predictors:    t2m  tp  u10  v10  ssrd  NAO
# 0  t2m  tp  u10  v10  ssrd  NAO
#      -> Selector method: Sequential
# 2 : optimal number of predictors and selected variables are Index(['ssrd', 'NAO'], dtype='object')
# R² (Coefficient of determinaiton): 0.38
# RMSE: 0.913661
# Mean Absolute Error): 0.59
# Done with ARD for Grafjellsbrea using Sequential. Selected predictors:    ssrd  NAO
# 0  ssrd  NAO
#      -> Selector method: TreeBased
# 3 : optimal number of predictors and selected variables are Index(['tp', 'u10', 'ssrd'], dtype='object')
# R² (Coefficient of determinaiton): 0.50
# RMSE: 0.820331
# Mean Absolute Error): 0.79
# Done with ARD for Grafjellsbrea using TreeBased. Selected predictors:    tp  u10  ssrd
# 0  tp  u10  ssrd
#
# --- Running Regressor: RandomForest ===
# Grafjellsbrea 60.1 6.38 1320.0
# Ba @ Grafjellsbrea: Missing months: 0
#      -> Selector method: Recursive
# 6 : optimal number of predictors and selected variables are Index(['t2m', 'tp', 'u10', 'v10', 'ssrd', 'NAO'], dtype='object')
# R² (Coefficient of determinaiton): 0.24
# RMSE: 1.005908
# Mean Absolute Error): 1.00
# Done with RandomForest for Grafjellsbrea using Recursive. Selected predictors:    t2m  tp  u10  v10  ssrd  NAO
# 0  t2m  tp  u10  v10  ssrd  NAO
#      -> Selector method: Sequential
# 2 : optimal number of predictors and selected variables are Index(['ssrd', 'NAO'], dtype='object')
# R² (Coefficient of determinaiton): 0.30
# RMSE: 0.965252
# Mean Absolute Error): 0.93
# Done with RandomForest for Grafjellsbrea using Sequential. Selected predictors:    ssrd  NAO
# 0  ssrd  NAO
#      -> Selector method: TreeBased
# 3 : optimal number of predictors and selected variables are Index(['tp', 'u10', 'ssrd'], dtype='object')
# R² (Coefficient of determinaiton): 0.19
# RMSE: 1.039520
# Mean Absolute Error): 1.04
# Done with RandomForest for Grafjellsbrea using TreeBased. Selected predictors:    tp  u10  ssrd
# 0  tp  u10  ssrd
#
# --- Running Regressor: XGBoost ===
# Grafjellsbrea 60.1 6.38 1320.0
# Ba @ Grafjellsbrea: Missing months: 0
#      -> Selector method: Recursive
# 6 : optimal number of predictors and selected variables are Index(['t2m', 'tp', 'u10', 'v10', 'ssrd', 'NAO'], dtype='object')
# R² (Coefficient of determinaiton): 0.22
# RMSE: 1.018285
# Mean Absolute Error): 1.02
# Done with XGBoost for Grafjellsbrea using Recursive. Selected predictors:    t2m  tp  u10  v10  ssrd  NAO
# 0  t2m  tp  u10  v10  ssrd  NAO
#      -> Selector method: Sequential
# 2 : optimal number of predictors and selected variables are Index(['ssrd', 'NAO'], dtype='object')
# R² (Coefficient of determinaiton): 0.19
# RMSE: 1.042016
# Mean Absolute Error): 1.00
# Done with XGBoost for Grafjellsbrea using Sequential. Selected predictors:    ssrd  NAO
# 0  ssrd  NAO
#      -> Selector method: TreeBased
# 3 : optimal number of predictors and selected variables are Index(['tp', 'u10', 'ssrd'], dtype='object')
# R² (Coefficient of determinaiton): -0.03
# RMSE: 1.174053
# Mean Absolute Error): 1.17
# Done with XGBoost for Grafjellsbrea using TreeBased. Selected predictors:    tp  u10  ssrd
# 0  tp  u10  ssrd
#
# --- Running Regressor: BayesianRidge ===
# Grafjellsbrea 60.1 6.38 1320.0
# Ba @ Grafjellsbrea: Missing months: 0
#      -> Selector method: Recursive
# 6 : optimal number of predictors and selected variables are Index(['t2m', 'tp', 'u10', 'v10', 'ssrd', 'NAO'], dtype='object')
# R² (Coefficient of determinaiton): 0.24
# RMSE: 1.006878
# Mean Absolute Error): 0.97
# Done with BayesianRidge for Grafjellsbrea using Recursive. Selected predictors:    t2m  tp  u10  v10  ssrd  NAO
# 0  t2m  tp  u10  v10  ssrd  NAO
#      -> Selector method: Sequential
# 2 : optimal number of predictors and selected variables are Index(['ssrd', 'NAO'], dtype='object')
# R² (Coefficient of determinaiton): 0.24
# RMSE: 1.006913
# Mean Absolute Error): 0.97
# Done with BayesianRidge for Grafjellsbrea using Sequential. Selected predictors:    ssrd  NAO
# 0  ssrd  NAO
#      -> Selector method: TreeBased
# 2 : optimal number of predictors and selected variables are Index(['tp', 'u10'], dtype='object')
# R² (Coefficient of determinaiton): 0.41
# RMSE: 0.885767
# Mean Absolute Error): 0.83
# Done with BayesianRidge for Grafjellsbrea using TreeBased. Selected predictors:    tp  u10
# 0  tp  u10
#
# --- Processing Station: Grasubreen ---
#
# --- Running Regressor: RidgeCV ===
# Grasubreen 61.65 8.62 2065.0
# Ba @ Grasubreen: Missing months: 0
#      -> Selector method: Recursive
# 6 : optimal number of predictors and selected variables are Index(['tp', 'u10', 'v10', 'ssrd', 'NAO', 'EA'], dtype='object')
# R² (Coefficient of determinaiton): 0.10
# RMSE: 0.878167
# Mean Absolute Error): 0.75
# Done with RidgeCV for Grasubreen using Recursive. Selected predictors:    tp  u10  v10  ssrd  NAO  EA
# 0  tp  u10  v10  ssrd  NAO  EA
#      -> Selector method: Sequential
# 2 : optimal number of predictors and selected variables are Index(['tp', 'NAO'], dtype='object')
# R² (Coefficient of determinaiton): 0.10
# RMSE: 0.877516
# Mean Absolute Error): 0.72
# Done with RidgeCV for Grasubreen using Sequential. Selected predictors:    tp  NAO
# 0  tp  NAO
#      -> Selector method: TreeBased
# 3 : optimal number of predictors and selected variables are Index(['tp', 'v10', 'ssrd'], dtype='object')
# R² (Coefficient of determinaiton): 0.01
# RMSE: 0.920964
# Mean Absolute Error): 0.81
# Done with RidgeCV for Grasubreen using TreeBased. Selected predictors:    tp  v10  ssrd
# 0  tp  v10  ssrd
#
# --- Running Regressor: Bagging ===
# Grasubreen 61.65 8.62 2065.0
# Ba @ Grasubreen: Missing months: 0
#      -> Selector method: Recursive
# 6 : optimal number of predictors and selected variables are Index(['tp', 'u10', 'v10', 'ssrd', 'NAO', 'EA'], dtype='object')
# R² (Coefficient of determinaiton): 0.02
# RMSE: 0.916228
# Mean Absolute Error): 0.74
# Done with Bagging for Grasubreen using Recursive. Selected predictors:    tp  u10  v10  ssrd  NAO  EA
# 0  tp  u10  v10  ssrd  NAO  EA
#      -> Selector method: Sequential
# 2 : optimal number of predictors and selected variables are Index(['tp', 'NAO'], dtype='object')
# R² (Coefficient of determinaiton): 0.28
# RMSE: 0.787806
# Mean Absolute Error): 0.66
# Done with Bagging for Grasubreen using Sequential. Selected predictors:    tp  NAO
# 0  tp  NAO
#      -> Selector method: TreeBased
# 2 : optimal number of predictors and selected variables are Index(['tp', 'v10'], dtype='object')
# R² (Coefficient of determinaiton): 0.37
# RMSE: 0.736571
# Mean Absolute Error): 0.59
# Done with Bagging for Grasubreen using TreeBased. Selected predictors:    tp  v10
# 0  tp  v10
#
# --- Running Regressor: ARD ===
# Grasubreen 61.65 8.62 2065.0
# Ba @ Grasubreen: Missing months: 0
#      -> Selector method: Recursive
# ...
# 2 : optimal number of predictors and selected variables are Index(['u10', 'NAO'], dtype='object')
# R² (Coefficient of determinaiton): 0.31
# RMSE: 0.772910
# Mean Absolute Error): 0.67
# Done with RandomForest for Nigardsbreen using Sequential. Selected predictors:    u10  NAO
# 0  u10  NAO
#      -> Selector method: TreeBased
# 2 : optimal number of predictors and selected variables are Index(['tp', 'u10'], dtype='object')
# R² (Coefficient of determinaiton): 0.42
# RMSE: 0.713461
# Mean Absolute Error): 0.62
# Done with RandomForest for Nigardsbreen using TreeBased. Selected predictors:    tp  u10
# 0  tp  u10
#
# --- Running Regressor: XGBoost ===
# Nigardsbreen 61.69 7.2 1136.0
# Ba @ Nigardsbreen: Missing months: 0
#      -> Selector method: Recursive
# 5 : optimal number of predictors and selected variables are Index(['t2m', 'tp', 'u10', 'ssrd', 'EA'], dtype='object')
# R² (Coefficient of determinaiton): 0.37
# RMSE: 0.741532
# Mean Absolute Error): 0.63
# Done with XGBoost for Nigardsbreen using Recursive. Selected predictors:    t2m  tp  u10  ssrd  EA
# 0  t2m  tp  u10  ssrd  EA
#      -> Selector method: Sequential
# 2 : optimal number of predictors and selected variables are Index(['u10', 'NAO'], dtype='object')
# R² (Coefficient of determinaiton): 0.04
# RMSE: 0.912267
# Mean Absolute Error): 0.71
# Done with XGBoost for Nigardsbreen using Sequential. Selected predictors:    u10  NAO
# 0  u10  NAO
#      -> Selector method: TreeBased
# 2 : optimal number of predictors and selected variables are Index(['tp', 'u10'], dtype='object')
# R² (Coefficient of determinaiton): 0.63
# RMSE: 0.564358
# Mean Absolute Error): 0.46
# Done with XGBoost for Nigardsbreen using TreeBased. Selected predictors:    tp  u10
# 0  tp  u10
#
# --- Running Regressor: BayesianRidge ===
# Nigardsbreen 61.69 7.2 1136.0
# Ba @ Nigardsbreen: Missing months: 0
#      -> Selector method: Recursive
# 5 : optimal number of predictors and selected variables are Index(['t2m', 'tp', 'u10', 'ssrd', 'EA'], dtype='object')
# R² (Coefficient of determinaiton): 0.34
# RMSE: 0.755609
# Mean Absolute Error): 0.67
# Done with BayesianRidge for Nigardsbreen using Recursive. Selected predictors:    t2m  tp  u10  ssrd  EA
# 0  t2m  tp  u10  ssrd  EA
#      -> Selector method: Sequential
# 2 : optimal number of predictors and selected variables are Index(['u10', 'NAO'], dtype='object')
# R² (Coefficient of determinaiton): 0.62
# RMSE: 0.574038
# Mean Absolute Error): 0.50
# Done with BayesianRidge for Nigardsbreen using Sequential. Selected predictors:    u10  NAO
# 0  u10  NAO
#      -> Selector method: TreeBased
# 2 : optimal number of predictors and selected variables are Index(['tp', 'u10'], dtype='object')
# R² (Coefficient of determinaiton): 0.56
# RMSE: 0.620536
# Mean Absolute Error): 0.54
# Done with BayesianRidge for Nigardsbreen using TreeBased. Selected predictors:    tp  u10
# 0  tp  u10
#
# --- Processing Station: Rembesdalskaka ---
#
# --- Running Regressor: RidgeCV ===
# Rembesdalskaka 60.54 7.37 1450.0
# Ba @ Rembesdalskaka: Missing months: 0
#      -> Selector method: Recursive
# 5 : optimal number of predictors and selected variables are Index(['t2m', 'tp', 'v10', 'NAO', 'EA'], dtype='object')
# R² (Coefficient of determinaiton): 0.61
# RMSE: 0.558914
# Mean Absolute Error): 0.44
# Done with RidgeCV for Rembesdalskaka using Recursive. Selected predictors:    t2m  tp  v10  NAO  EA
# 0  t2m  tp  v10  NAO  EA
#      -> Selector method: Sequential
# 2 : optimal number of predictors and selected variables are Index(['u10', 'v10'], dtype='object')
# R² (Coefficient of determinaiton): 0.68
# RMSE: 0.511594
# Mean Absolute Error): 0.44
# Done with RidgeCV for Rembesdalskaka using Sequential. Selected predictors:    u10  v10
# 0  u10  v10
#      -> Selector method: TreeBased
# 3 : optimal number of predictors and selected variables are Index(['tp', 'u10', 'NAO'], dtype='object')
# R² (Coefficient of determinaiton): 0.70
# RMSE: 0.489071
# Mean Absolute Error): 0.38
# Done with RidgeCV for Rembesdalskaka using TreeBased. Selected predictors:    tp  u10  NAO
# 0  tp  u10  NAO
#
# --- Running Regressor: Bagging ===
# Rembesdalskaka 60.54 7.37 1450.0
# Ba @ Rembesdalskaka: Missing months: 0
#      -> Selector method: Recursive
# 5 : optimal number of predictors and selected variables are Index(['t2m', 'tp', 'v10', 'NAO', 'EA'], dtype='object')
# R² (Coefficient of determinaiton): 0.39
# RMSE: 0.703206
# Mean Absolute Error): 0.57
# Done with Bagging for Rembesdalskaka using Recursive. Selected predictors:    t2m  tp  v10  NAO  EA
# 0  t2m  tp  v10  NAO  EA
#      -> Selector method: Sequential
# 2 : optimal number of predictors and selected variables are Index(['u10', 'v10'], dtype='object')
# R² (Coefficient of determinaiton): 0.48
# RMSE: 0.647023
# Mean Absolute Error): 0.54
# Done with Bagging for Rembesdalskaka using Sequential. Selected predictors:    u10  v10
# 0  u10  v10
#      -> Selector method: TreeBased
# 3 : optimal number of predictors and selected variables are Index(['tp', 'u10', 'NAO'], dtype='object')
# R² (Coefficient of determinaiton): 0.41
# RMSE: 0.691615
# Mean Absolute Error): 0.56
# Done with Bagging for Rembesdalskaka using TreeBased. Selected predictors:    tp  u10  NAO
# 0  tp  u10  NAO
#
# --- Running Regressor: ARD ===
# Rembesdalskaka 60.54 7.37 1450.0
# Ba @ Rembesdalskaka: Missing months: 0
#      -> Selector method: Recursive
# 5 : optimal number of predictors and selected variables are Index(['t2m', 'tp', 'v10', 'NAO', 'EA'], dtype='object')
# R² (Coefficient of determinaiton): 0.57
# RMSE: 0.593135
# Mean Absolute Error): 0.51
# Done with ARD for Rembesdalskaka using Recursive. Selected predictors:    t2m  tp  v10  NAO  EA
# 0  t2m  tp  v10  NAO  EA
#      -> Selector method: Sequential
# 2 : optimal number of predictors and selected variables are Index(['u10', 'v10'], dtype='object')
# R² (Coefficient of determinaiton): 0.81
# RMSE: 0.388092
# Mean Absolute Error): 0.30
# Done with ARD for Rembesdalskaka using Sequential. Selected predictors:    u10  v10
# 0  u10  v10
#      -> Selector method: TreeBased
# 2 : optimal number of predictors and selected variables are Index(['tp', 'u10'], dtype='object')
# R² (Coefficient of determinaiton): 0.59
# RMSE: 0.578229
# Mean Absolute Error): 0.48
# Done with ARD for Rembesdalskaka using TreeBased. Selected predictors:    tp  u10
# 0  tp  u10
#
# --- Running Regressor: RandomForest ===
# Rembesdalskaka 60.54 7.37 1450.0
# Ba @ Rembesdalskaka: Missing months: 0
#      -> Selector method: Recursive
# 5 : optimal number of predictors and selected variables are Index(['t2m', 'tp', 'v10', 'NAO', 'EA'], dtype='object')
# R² (Coefficient of determinaiton): 0.38
# RMSE: 0.710439
# Mean Absolute Error): 0.58
# Done with RandomForest for Rembesdalskaka using Recursive. Selected predictors:    t2m  tp  v10  NAO  EA
# 0  t2m  tp  v10  NAO  EA
#      -> Selector method: Sequential
# 2 : optimal number of predictors and selected variables are Index(['u10', 'v10'], dtype='object')
# R² (Coefficient of determinaiton): 0.47
# RMSE: 0.652466
# Mean Absolute Error): 0.55
# Done with RandomForest for Rembesdalskaka using Sequential. Selected predictors:    u10  v10
# 0  u10  v10
#      -> Selector method: TreeBased
# 3 : optimal number of predictors and selected variables are Index(['tp', 'u10', 'NAO'], dtype='object')
# R² (Coefficient of determinaiton): 0.40
# RMSE: 0.699190
# Mean Absolute Error): 0.57
# Done with RandomForest for Rembesdalskaka using TreeBased. Selected predictors:    tp  u10  NAO
# 0  tp  u10  NAO
#
# --- Running Regressor: XGBoost ===
# Rembesdalskaka 60.54 7.37 1450.0
# Ba @ Rembesdalskaka: Missing months: 0
#      -> Selector method: Recursive
# 5 : optimal number of predictors and selected variables are Index(['t2m', 'tp', 'v10', 'NAO', 'EA'], dtype='object')
# R² (Coefficient of determinaiton): 0.14
# RMSE: 0.833866
# Mean Absolute Error): 0.67
# Done with XGBoost for Rembesdalskaka using Recursive. Selected predictors:    t2m  tp  v10  NAO  EA
# 0  t2m  tp  v10  NAO  EA
#      -> Selector method: Sequential
# 2 : optimal number of predictors and selected variables are Index(['u10', 'v10'], dtype='object')
# R² (Coefficient of determinaiton): 0.00
# RMSE: 0.897702
# Mean Absolute Error): 0.76
# Done with XGBoost for Rembesdalskaka using Sequential. Selected predictors:    u10  v10
# 0  u10  v10
#      -> Selector method: TreeBased
# 2 : optimal number of predictors and selected variables are Index(['tp', 'u10'], dtype='object')
# R² (Coefficient of determinaiton): -0.18
# RMSE: 0.976786
# Mean Absolute Error): 0.88
# Done with XGBoost for Rembesdalskaka using TreeBased. Selected predictors:    tp  u10
# 0  tp  u10
#
# --- Running Regressor: BayesianRidge ===
# Rembesdalskaka 60.54 7.37 1450.0
# Ba @ Rembesdalskaka: Missing months: 0
#      -> Selector method: Recursive
# 5 : optimal number of predictors and selected variables are Index(['t2m', 'tp', 'v10', 'NAO', 'EA'], dtype='object')
# R² (Coefficient of determinaiton): 0.62
# RMSE: 0.553185
# Mean Absolute Error): 0.43
# Done with BayesianRidge for Rembesdalskaka using Recursive. Selected predictors:    t2m  tp  v10  NAO  EA
# 0  t2m  tp  v10  NAO  EA
#      -> Selector method: Sequential
# 2 : optimal number of predictors and selected variables are Index(['u10', 'v10'], dtype='object')
# R² (Coefficient of determinaiton): 0.81
# RMSE: 0.390966
# Mean Absolute Error): 0.30
# Done with BayesianRidge for Rembesdalskaka using Sequential. Selected predictors:    u10  v10
# 0  u10  v10
#      -> Selector method: TreeBased
# 2 : optimal number of predictors and selected variables are Index(['tp', 'u10'], dtype='object')
# R² (Coefficient of determinaiton): 0.74
# RMSE: 0.457033
# Mean Absolute Error): 0.39
# Done with BayesianRidge for Rembesdalskaka using TreeBased. Selected predictors:    tp  u10
# 0  tp  u10
#
# --- Processing Station: Storbreen ---
#
# --- Running Regressor: RidgeCV ===
# Storebreen 61.57 8.13 1700.0
# Ba @ Storbreen: Missing months: 0
#      -> Selector method: Recursive
# 5 : optimal number of predictors and selected variables are Index(['tp', 'u10', 'v10', 'NAO', 'EA'], dtype='object')
# R² (Coefficient of determinaiton): 0.41
# RMSE: 0.771422
# Mean Absolute Error): 0.62
# Done with RidgeCV for Storbreen using Recursive. Selected predictors:    tp  u10  v10  NAO  EA
# 0  tp  u10  v10  NAO  EA
#      -> Selector method: Sequential
# 2 : optimal number of predictors and selected variables are Index(['tp', 'u10'], dtype='object')
# R² (Coefficient of determinaiton): 0.22
# RMSE: 0.883482
# Mean Absolute Error): 0.72
# Done with RidgeCV for Storbreen using Sequential. Selected predictors:    tp  u10
# 0  tp  u10
#      -> Selector method: TreeBased
# 2 : optimal number of predictors and selected variables are Index(['tp', 'v10'], dtype='object')
# R² (Coefficient of determinaiton): 0.05
# RMSE: 0.976967
# Mean Absolute Error): 0.85
# Done with RidgeCV for Storbreen using TreeBased. Selected predictors:    tp  v10
# 0  tp  v10
#
# --- Running Regressor: Bagging ===
# Storebreen 61.57 8.13 1700.0
# Ba @ Storbreen: Missing months: 0
#      -> Selector method: Recursive
# 5 : optimal number of predictors and selected variables are Index(['tp', 'u10', 'v10', 'NAO', 'EA'], dtype='object')
# R² (Coefficient of determinaiton): 0.45
# RMSE: 0.744445
# Mean Absolute Error): 0.63
# Done with Bagging for Storbreen using Recursive. Selected predictors:    tp  u10  v10  NAO  EA
# 0  tp  u10  v10  NAO  EA
#      -> Selector method: Sequential
# 2 : optimal number of predictors and selected variables are Index(['tp', 'u10'], dtype='object')
# R² (Coefficient of determinaiton): 0.36
# RMSE: 0.798804
# Mean Absolute Error): 0.68
# Done with Bagging for Storbreen using Sequential. Selected predictors:    tp  u10
# 0  tp  u10
#      -> Selector method: TreeBased
# 2 : optimal number of predictors and selected variables are Index(['tp', 'v10'], dtype='object')
# R² (Coefficient of determinaiton): 0.41
# RMSE: 0.770817
# Mean Absolute Error): 0.72
# Done with Bagging for Storbreen using TreeBased. Selected predictors:    tp  v10
# 0  tp  v10
#
# --- Running Regressor: ARD ===
# Storebreen 61.57 8.13 1700.0
# Ba @ Storbreen: Missing months: 0
#      -> Selector method: Recursive
# 5 : optimal number of predictors and selected variables are Index(['tp', 'u10', 'v10', 'NAO', 'EA'], dtype='object')
# R² (Coefficient of determinaiton): 0.41
# RMSE: 0.767656
# Mean Absolute Error): 0.63
# Done with ARD for Storbreen using Recursive. Selected predictors:    tp  u10  v10  NAO  EA
# 0  tp  u10  v10  NAO  EA
#      -> Selector method: Sequential
# 2 : optimal number of predictors and selected variables are Index(['tp', 'u10'], dtype='object')
# R² (Coefficient of determinaiton): 0.40
# RMSE: 0.776975
# Mean Absolute Error): 0.64
# Done with ARD for Storbreen using Sequential. Selected predictors:    tp  u10
# 0  tp  u10
#      -> Selector method: TreeBased
# 3 : optimal number of predictors and selected variables are Index(['tp', 'u10', 'v10'], dtype='object')
# R² (Coefficient of determinaiton): 0.41
# RMSE: 0.767609
# Mean Absolute Error): 0.63
# Done with ARD for Storbreen using TreeBased. Selected predictors:    tp  u10  v10
# 0  tp  u10  v10
#
# --- Running Regressor: RandomForest ===
# Storebreen 61.57 8.13 1700.0
# Ba @ Storbreen: Missing months: 0
#      -> Selector method: Recursive
# 5 : optimal number of predictors and selected variables are Index(['tp', 'u10', 'v10', 'NAO', 'EA'], dtype='object')
# R² (Coefficient of determinaiton): 0.44
# RMSE: 0.748680
# Mean Absolute Error): 0.63
# Done with RandomForest for Storbreen using Recursive. Selected predictors:    tp  u10  v10  NAO  EA
# 0  tp  u10  v10  NAO  EA
#      -> Selector method: Sequential
# 2 : optimal number of predictors and selected variables are Index(['tp', 'u10'], dtype='object')
# R² (Coefficient of determinaiton): 0.37
# RMSE: 0.795888
# Mean Absolute Error): 0.68
# Done with RandomForest for Storbreen using Sequential. Selected predictors:    tp  u10
# 0  tp  u10
#      -> Selector method: TreeBased
# 2 : optimal number of predictors and selected variables are Index(['tp', 'v10'], dtype='object')
# R² (Coefficient of determinaiton): 0.41
# RMSE: 0.772752
# Mean Absolute Error): 0.72
# Done with RandomForest for Storbreen using TreeBased. Selected predictors:    tp  v10
# 0  tp  v10
#
# --- Running Regressor: XGBoost ===
# Storebreen 61.57 8.13 1700.0
# Ba @ Storbreen: Missing months: 0
#      -> Selector method: Recursive
# 5 : optimal number of predictors and selected variables are Index(['tp', 'u10', 'v10', 'NAO', 'EA'], dtype='object')
# R² (Coefficient of determinaiton): 0.25
# RMSE: 0.865079
# Mean Absolute Error): 0.65
# Done with XGBoost for Storbreen using Recursive. Selected predictors:    tp  u10  v10  NAO  EA
# 0  tp  u10  v10  NAO  EA
#      -> Selector method: Sequential
# 2 : optimal number of predictors and selected variables are Index(['tp', 'u10'], dtype='object')
# R² (Coefficient of determinaiton): 0.07
# RMSE: 0.967982
# Mean Absolute Error): 0.76
# Done with XGBoost for Storbreen using Sequential. Selected predictors:    tp  u10
# 0  tp  u10
#      -> Selector method: TreeBased
# 3 : optimal number of predictors and selected variables are Index(['tp', 'u10', 'v10'], dtype='object')
# R² (Coefficient of determinaiton): 0.06
# RMSE: 0.968803
# Mean Absolute Error): 0.72
# Done with XGBoost for Storbreen using TreeBased. Selected predictors:    tp  u10  v10
# 0  tp  u10  v10
#
# --- Running Regressor: BayesianRidge ===
# Storebreen 61.57 8.13 1700.0
# Ba @ Storbreen: Missing months: 0
#      -> Selector method: Recursive
# 5 : optimal number of predictors and selected variables are Index(['tp', 'u10', 'v10', 'NAO', 'EA'], dtype='object')
# R² (Coefficient of determinaiton): 0.48
# RMSE: 0.724085
# Mean Absolute Error): 0.58
# Done with BayesianRidge for Storbreen using Recursive. Selected predictors:    tp  u10  v10  NAO  EA
# 0  tp  u10  v10  NAO  EA
#      -> Selector method: Sequential
# 2 : optimal number of predictors and selected variables are Index(['tp', 'u10'], dtype='object')
# R² (Coefficient of determinaiton): 0.29
# RMSE: 0.843587
# Mean Absolute Error): 0.70
# Done with BayesianRidge for Storbreen using Sequential. Selected predictors:    tp  u10
# 0  tp  u10
#      -> Selector method: TreeBased
# 2 : optimal number of predictors and selected variables are Index(['tp', 'v10'], dtype='object')
# R² (Coefficient of determinaiton): 0.18
# RMSE: 0.907026
# Mean Absolute Error): 0.76
# Done with BayesianRidge for Storbreen using TreeBased. Selected predictors:    tp  v10
# 0  tp  v10

# %%
metrics_path = os.path.join(results_dir, "model_metrics_ba.csv")
results_df.to_csv(metrics_path, index=False)

# %%
# Load your updated CSV
metrics_path = os.path.join(results_dir, "model_metrics_ba.csv")
df = pd.read_csv(metrics_path)
#df= results_df

# Define custom colors for Selector methods
colors = {
    "Rec": "#ca0020",   # red
    "Seq": "#0571b0",  # blue
    "Tree": "#fdb863"    # orange-yellow
}

gridline_color = "#d3d3d3"
variables = ["Ba"]

for var in variables:
    fig, ax = plt.subplots(figsize=(15, 8))
    sns.boxplot(data=df[df["Variable"] == var], x="Regressor", y="R2", hue="Selector", palette=colors, ax=ax)

    ax.set_title(f"Test R² Scores for {var} (1950 - 2023)", fontsize=18, fontweight="bold")
    ax.set_ylabel("Test R²", fontsize=18, fontweight="bold")
    ax.set_xlabel("Regressor", fontsize=18, fontweight="bold")
    ax.grid(True, linestyle="--", color=gridline_color)
    ax.legend(title="Selector", title_fontsize=18, fontsize=18)
    ax.set_ylim(-1, 1)
    plt.xticks(rotation=45, size=18)
    plt.yticks(size=16)
    plt.tight_layout()
    #plt.savefig(f"boxplot_r2_{var}_complete.png", dpi=800)
    plt.show()

# %%
# Load results
results_df = pd.read_csv(r"C:\Users\danis\Desktop\Danish\Scripts_Python\Results\model_metrics_ba.csv")

# Create combined model column
results_df["Model"] = results_df["Regressor"] + " - " + results_df["Selector"]

# Pivot table (handle duplicates by taking the mean)
#pivot_df = results_df.pivot(index="Glacier", columns="Model", values="RMSE")
pivot_df = results_df.pivot_table(index="Glacier", columns="Model", values="RMSE", aggfunc="mean")

gridline_color = "#d3d3d3"  # light grey
plt.figure(figsize=(20, 10))
sns.heatmap(
    pivot_df,
    annot=True,
    fmt=".2f",
    cmap="RdYlBu_r",
    linewidths=0.5,
    linecolor=gridline_color,
    cbar_kws={'label': 'RMSE'},
    annot_kws={"fontsize": 16, "fontweight": "bold"},
    vmax= 1.6,
    vmin= 0.3
)

cbar = plt.gcf().axes[-1]
cbar.tick_params(labelsize=16)
cbar.set_ylabel("RMSE", fontsize=16, fontweight="bold")

plt.title("Test RMSE Heatmap for Ba: Glacier × Model (1950-2023)", fontsize=18, fontweight="bold", pad=15)
plt.xlabel("Model (Regressor + Selector)", fontsize=16, fontweight="bold", labelpad=10)
plt.ylabel("Glacier", fontsize=16, fontweight="bold", labelpad=10, rotation=90)

plt.xticks(rotation=45, ha='right', fontsize=18)
plt.yticks(rotation=45, fontsize=18)

plt.tight_layout()
plt.subplots_adjust(left=0.07, right=0.95, top=0.93, bottom=0.15)
#plt.savefig(r"C:\Users\danis\Desktop\Danish\Py-Plots\07- Ba Model Routine\Complete\heatmap_rmse_ba_complete.png", dpi=800, bbox_inches='tight')
plt.show()

# %%
df= pd.read_csv(metrics_path)

colors = {
    "Recursive": "#ca0020", #from the RdBu theme
    "Sequential": "#0571b0",
    "TreeBased": "#fdb863" 
}
gridline_color = "#d3d3d3"  # light grey

fig, ax = plt.subplots(1, 1, sharex=False, figsize=(15, 8))
sns.boxplot(data=df, x="Regressor", y="R2", hue="Selector", palette=colors, ax=ax)

ax.set_title("Test R² Scores by Regressor and Selector", fontsize=14, fontweight="bold")
ax.set_ylabel("Test R²", fontsize=14, fontweight="bold")
ax.set_xlabel("Regressor", fontsize=14, fontweight="bold")

ax.grid(True, linestyle="--", color=gridline_color)
ax.legend(title="Selector", title_fontsize=14, fontsize=14)

plt.xticks(rotation=45, fontsize=14)
plt.yticks(fontsize=14)
plt.tight_layout()
plt.subplots_adjust(left=0.05, right=0.95, top=0.97, bottom=0.05)
plt.show()

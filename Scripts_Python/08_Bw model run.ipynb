# %%
# importing packages

import os 
import pandas as pd
import numpy as np
np.int= int
import xarray as xr
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import KFold
from sklearn.linear_model import RidgeCV

from pyESD.ESD_utils import store_pickle, Dataset
from pyESD.Weatherstation import read_station_csv
from pyESD.standardizer import MonthlyStandardizer
from pyESD.teleconnections import NAO, eof_analysis
from pyESD.metrics import Evaluate
from pyESD.models import Regressors
from pyESD.standardizer import YearlyStandardizer

# %%
cachedir = r"C:\Users\danis\Desktop\Danish\ERA5 Data\PYESD_CACHE"
os.makedirs(cachedir, exist_ok=True)

# %%
variable= ['Bw'] # or Bs, Ba

# time splits
train_range        = pd.date_range("1950-01-01", "2010-01-01", freq="YS")
test_range         = pd.date_range("2011-01-01", "2023-01-01", freq="YS")
complete_range     = pd.date_range("1950-01-01", "2023-01-01", freq="YS")

# pre2k_complete      = pd.date_range("1950-01-01", "2000-01-01", freq="YS")
# pre2k_train_range   = pd.date_range("1950-01-01", "1985-01-01", freq="YS")
# pre2k_test_range    = pd.date_range("1986-01-01", "2000-01-01", freq="YS")

# post2k_complete     = pd.date_range("2000-01-01", "2023-01-01", freq="YS")
# post2k_train_range  = pd.date_range("2000-01-01", "2012-01-01", freq="YS")
# post2k_test_range   = pd.date_range("2013-01-01", "2023-01-01", freq="YS")

predictors=["t2m", "tp", "u10", "v10", "ssrd", "NAO", "EA"]

# %%
djf_mean_dir = r"C:\Users\danis\Desktop\Danish\ERA5 Data\DJF_MEANS"
predictor_dir= r"C:\Users\danis\Desktop\Danish\ERA5 Data"

ERA5Data = Dataset(name="ERA5", domain_name='NH', variables={
    "t2m":  os.path.join(djf_mean_dir, "DJF_MEAN_t2m.nc"),
    "tp":   os.path.join(djf_mean_dir, "DJF_MEAN_tp.nc"),
    "v10":  os.path.join(djf_mean_dir, "DJF_MEAN_v10.nc"),
    "u10":  os.path.join(djf_mean_dir, "DJF_MEAN_u10.nc"),
    "ssrd": os.path.join(djf_mean_dir, "DJF_MEAN_ssrd.nc"),
    "msl":  os.path.join(predictor_dir, "msl.nc"), 
})
ERA5Data

# %%
glaciernames = ['Alfotbreen', 'Austdalsbreen', 'Engabreen', 'Grafjellsbrea', 'Grasubreen', 
                             'Hansebreen', 'Hellstugubreen', 'Langfjordjokelen', 'Nigardsbreen', 'Rembesdalskaka', 'Storbreen']


## Creating short form dictinary for glacier names

glacier_shortnames = {'Alfotbreen': 'Alf', 
                        'Austdalsbreen': 'Aus', 
                        'Engabreen': 'Eng', 
                        'Grafjellsbrea': 'Graf', 
                        'Grasubreen': 'Gras', 
                        'Hansebreen': 'Han', 
                        'Hellstugubreen': 'Hell', 
                        'Langfjordjokelen': 'Lan',
                        'Nigardsbreen': 'Nig', 
                        'Rembesdalskaka': 'Rem', 
                        'Storbreen': 'Sto'}


glacier_datadir= r"C:\Users\danis\Desktop\Danish\NVE\glaciers\Mass Balance\Cleaned"
glaciers = {}

# %%
regressors= ['RidgeCV', 'Bagging', 'ARD', 'RandomForest', 'XGBoost', 'BayesianRidge']

regressor_shortnames = {
    "RandomForest": "RF",
    "ARD": "ARD",
    "RidgeCV": "Ridge",
    "XGBoost": "XGB",
    "Bagging": "Bag",
    "BayesianRidge": "BYR"

}
selector_shortnames = {
    "Recursive": "Rec",
    "Sequential": "Seq",
    "TreeBased": "Tree"
}

# %%
results = []
# results_dir= r"C:\Users\danis\Desktop\Danish\Scripts_Python\Results"
results_dir = r"C:\Users\danis\Desktop\Danish\Thesis Model Results (Appendix)"

# %%
import xarray as xr

t2m_djf = xr.open_dataset(r"C:\Users\danis\Desktop\Danish\ERA5 Data\DJF_MEANS\DJF_MEAN_t2m.nc")
print(t2m_djf)
print(t2m_djf['t2m'].time)
# Out:
# <xarray.Dataset> Size: 1GB
# Dimensions:    (latitude: 721, longitude: 1440, time: 297)
# Coordinates:
#   * latitude   (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#   * longitude  (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     number     int64 8B ...
#   * time       (time) datetime64[ns] 2kB 1950-01-01 1951-01-01 ... 2024-01-01
# Data variables:
#     t2m        (time, latitude, longitude) float32 1GB ...
# <xarray.DataArray 'time' (time: 297)> Size: 2kB
# array(['1950-01-01T00:00:00.000000000', '1951-01-01T00:00:00.000000000',
#        '1951-01-01T00:00:00.000000000', ..., '2024-01-01T00:00:00.000000000',
#        '2024-01-01T00:00:00.000000000', '2024-01-01T00:00:00.000000000'],
#       dtype='datetime64[ns]')
# Coordinates:
#     number   int64 8B ...
#   * time     (time) datetime64[ns] 2kB 1950-01-01 1951-01-01 ... 2024-01-01

# %%
for variable in ['Bw']:
    print(f"\n===== Running model for variable: {variable} =====")
    
    for name in glacier_shortnames:
        print(f"\n--- Processing Station: {name} ---")

        for regressor in regressors:
            print (f"\n--- Running Regressor: {regressor} ===")

            glacier_file = os.path.join(glacier_datadir, f"{name}_cleaned.csv")
            GO = read_station_csv(filename=glacier_file, varname=variable) 
            glaciers[name] = GO

            available_train_range = [d for d in train_range if d in GO.get_var(variable, None).index]
            available_test_range  = [d for d in test_range if d in GO.get_var(variable, None).index]

            # 1. defining model predictors
            GO.set_predictors(variable=variable, predictors= predictors, 
                              cachedir=cachedir)

            y = GO.get_var(variable, available_train_range)
            print(f"{variable} @ {name}: Missing months:", y.isna().sum())
            if y.dropna().shape[0] < 12:
                print(f"⚠️ Skipping {name} — insufficient glacier data")
                continue

            # 2. setting standardardizer
            GO.set_standardizer(variable, standardizer= YearlyStandardizer(detrending=True, scaling=True))
    
            # 3. defining scoring metrics
            scoring= ['neg_root_mean_squared_error', 'r2', 'neg_mean_absolute_error']
    
             # 4. training model
            GO.set_model(variable=variable,
                         method= regressor,
                         predictor_dataset=ERA5Data,
                         daterange=available_train_range,
                         scoring= scoring,
                         cv=KFold(n_splits=10))
    
            # 5. setting selectors
            for selector_method in ['Recursive', 'Sequential', 'TreeBased']:
                print(f"     -> Selector method: {selector_method}")
    
                if selector_method == 'Recursive':
                    GO.fit(variable, available_train_range, ERA5Data, fit_predictors=True,
                           predictor_selector=True, selector_method=selector_method,
                           selector_regressor= 'ARD', cal_relative_importance=False)
                    
                elif selector_method == 'TreeBased':
                    GO.fit(variable, available_train_range, ERA5Data, fit_predictors=True,
                           predictor_selector=True, selector_method=selector_method,
                           selector_regressor='ExtraTree')
    
                elif selector_method == 'Sequential':
                    GO.fit(variable, available_train_range, ERA5Data, fit_predictors=True,
                           predictor_selector=True, selector_method=selector_method,
                           select_regressor= 'ARD', num_predictors= 2, selector_direction='forward')
    
                else:
                    raise ValueError('Selector method not recognized')
    
                
                selected_predictors = GO.selected_names(variable)
                ypred = GO.predict(variable, available_test_range, ERA5Data)
    
                # 6. cross validate and predict for training period
                #score_1950to2010, ypred_1950to2010 = GO.cross_validate_and_predict(variable, available_train_range, ERA5Data)
                score_train, ypred_train= GO.cross_validate_and_predict(variable, available_train_range, ERA5Data)

                # 7. prediction for training period
                #ypred_1950to2010 = GO.predict(variable, available_train_range, ERA5Data)
                ypred_train = GO.predict(variable, available_train_range, ERA5Data)

                # 8. prediction for testing period
                #ypred_2011to2022 = GO.predict(variable, available_test_range , ERA5Data)
                ypred_test = GO.predict(variable, available_test_range, ERA5Data)
          
                # 9. Evaluate metrics using test predictions
                y_true_test = GO.get_var(variable, available_test_range)
                evaluator = Evaluate(y_true_test, ypred_test)
                r2 = evaluator.R2_score()
                rmse = evaluator.RMSE()
                mae = evaluator.MAE()
                            
                # 10. Save results
                # results.append({
                #     "Variable": variable,
                #     "Glacier": glacier_shortnames[name],
                #     "Regressor": regressor_shortnames[regressor],
                #     "Selector": selector_shortnames[selector_method],
                #     "Predictors": selected_predictors,
                #     "R2": r2,
                #     "RMSE": rmse,
                #     "MAE": mae
                # })

                # Saving results in a structured format for thesis
                results.append({
                    "Glacier": glacier_shortnames[name],
                    "Model_Combination": f"{regressor_shortnames[regressor]} + {selector_shortnames[selector_method]}",
                    "Model_Type": "Linear" if regressor_shortnames[regressor] in ["RidgeCV", "ARD", "BayesianRidge"] else "Non-linear",
                    "R2": round(r2, 3),
                    "RMSE": round(rmse, 3)
                })

                df_preds = pd.DataFrame({
                    "Date": GO.get_var(variable, available_train_range).index,
                    "Observed": GO.get_var(variable, available_train_range).values,
                    "Predicted": ypred_train
                })
    
                #filename = os.path.join(results_dir, f"predictions_{name}_{regressor}_{selector_method}.csv")
                #df_preds.to_csv(filename, index=False)
    
                print(f"Done with {regressor} for {name} using {selector_method}. Selected predictors: {selected_predictors}")

results_df= pd.DataFrame(results)
# Out:
# ===== Running model for variable: Bw =====
#
# --- Processing Station: Alfotbreen ---
#
# --- Running Regressor: RidgeCV ===
# Alfotbreen 61.75 5.65 1180.0
# Bw @ Alfotbreen: Missing months: 0
#      -> Selector method: Recursive
# 5 : optimal number of predictors and selected variables are Index(['tp', 'u10', 'v10', 'NAO', 'EA'], dtype='object')
# R² (Coefficient of determinaiton): 0.11
# RMSE: 0.627200
# Mean Absolute Error): 0.59
# Done with RidgeCV for Alfotbreen using Recursive. Selected predictors:    tp  u10  v10  NAO  EA
# 0  tp  u10  v10  NAO  EA
#      -> Selector method: Sequential
# 2 : optimal number of predictors and selected variables are Index(['u10', 'ssrd'], dtype='object')
# R² (Coefficient of determinaiton): -0.39
# RMSE: 0.784385
# Mean Absolute Error): 0.69
# Done with RidgeCV for Alfotbreen using Sequential. Selected predictors:    u10  ssrd
# 0  u10  ssrd
#      -> Selector method: TreeBased
# 2 : optimal number of predictors and selected variables are Index(['tp', 'u10'], dtype='object')
# R² (Coefficient of determinaiton): -0.32
# RMSE: 0.764291
# Mean Absolute Error): 0.67
# Done with RidgeCV for Alfotbreen using TreeBased. Selected predictors:    tp  u10
# 0  tp  u10
#
# --- Running Regressor: Bagging ===
# Alfotbreen 61.75 5.65 1180.0
# Bw @ Alfotbreen: Missing months: 0
#      -> Selector method: Recursive
# 5 : optimal number of predictors and selected variables are Index(['tp', 'u10', 'v10', 'NAO', 'EA'], dtype='object')
# R² (Coefficient of determinaiton): -0.21
# RMSE: 0.732477
# Mean Absolute Error): 0.62
# Done with Bagging for Alfotbreen using Recursive. Selected predictors:    tp  u10  v10  NAO  EA
# 0  tp  u10  v10  NAO  EA
#      -> Selector method: Sequential
# 2 : optimal number of predictors and selected variables are Index(['u10', 'ssrd'], dtype='object')
# R² (Coefficient of determinaiton): -0.43
# RMSE: 0.797795
# Mean Absolute Error): 0.67
# Done with Bagging for Alfotbreen using Sequential. Selected predictors:    u10  ssrd
# 0  u10  ssrd
#      -> Selector method: TreeBased
# 2 : optimal number of predictors and selected variables are Index(['tp', 'u10'], dtype='object')
# R² (Coefficient of determinaiton): -0.40
# RMSE: 0.786781
# Mean Absolute Error): 0.69
# Done with Bagging for Alfotbreen using TreeBased. Selected predictors:    tp  u10
# 0  tp  u10
#
# --- Running Regressor: ARD ===
# Alfotbreen 61.75 5.65 1180.0
# Bw @ Alfotbreen: Missing months: 0
#      -> Selector method: Recursive
# 5 : optimal number of predictors and selected variables are Index(['tp', 'u10', 'v10', 'NAO', 'EA'], dtype='object')
# R² (Coefficient of determinaiton): 0.26
# RMSE: 0.573947
# Mean Absolute Error): 0.52
# Done with ARD for Alfotbreen using Recursive. Selected predictors:    tp  u10  v10  NAO  EA
# 0  tp  u10  v10  NAO  EA
#      -> Selector method: Sequential
# 2 : optimal number of predictors and selected variables are Index(['u10', 'ssrd'], dtype='object')
# R² (Coefficient of determinaiton): -0.34
# RMSE: 0.770860
# Mean Absolute Error): 0.67
# Done with ARD for Alfotbreen using Sequential. Selected predictors:    u10  ssrd
# 0  u10  ssrd
#      -> Selector method: TreeBased
# 2 : optimal number of predictors and selected variables are Index(['tp', 'u10'], dtype='object')
# R² (Coefficient of determinaiton): 0.26
# RMSE: 0.573950
# Mean Absolute Error): 0.52
# Done with ARD for Alfotbreen using TreeBased. Selected predictors:    tp  u10
# 0  tp  u10
#
# --- Running Regressor: RandomForest ===
# Alfotbreen 61.75 5.65 1180.0
# Bw @ Alfotbreen: Missing months: 0
#      -> Selector method: Recursive
# 5 : optimal number of predictors and selected variables are Index(['tp', 'u10', 'v10', 'NAO', 'EA'], dtype='object')
# R² (Coefficient of determinaiton): -0.23
# RMSE: 0.738627
# Mean Absolute Error): 0.62
# Done with RandomForest for Alfotbreen using Recursive. Selected predictors:    tp  u10  v10  NAO  EA
# 0  tp  u10  v10  NAO  EA
#      -> Selector method: Sequential
# 2 : optimal number of predictors and selected variables are Index(['u10', 'ssrd'], dtype='object')
# R² (Coefficient of determinaiton): -0.42
# RMSE: 0.794589
# Mean Absolute Error): 0.66
# Done with RandomForest for Alfotbreen using Sequential. Selected predictors:    u10  ssrd
# 0  u10  ssrd
#      -> Selector method: TreeBased
# 2 : optimal number of predictors and selected variables are Index(['tp', 'u10'], dtype='object')
# R² (Coefficient of determinaiton): -0.40
# RMSE: 0.789039
# Mean Absolute Error): 0.70
# Done with RandomForest for Alfotbreen using TreeBased. Selected predictors:    tp  u10
# 0  tp  u10
#
# --- Running Regressor: XGBoost ===
# Alfotbreen 61.75 5.65 1180.0
# Bw @ Alfotbreen: Missing months: 0
#      -> Selector method: Recursive
# 5 : optimal number of predictors and selected variables are Index(['tp', 'u10', 'v10', 'NAO', 'EA'], dtype='object')
# R² (Coefficient of determinaiton): -0.28
# RMSE: 0.754621
# Mean Absolute Error): 0.66
# Done with XGBoost for Alfotbreen using Recursive. Selected predictors:    tp  u10  v10  NAO  EA
# 0  tp  u10  v10  NAO  EA
#      -> Selector method: Sequential
# 2 : optimal number of predictors and selected variables are Index(['u10', 'ssrd'], dtype='object')
# R² (Coefficient of determinaiton): -1.17
# RMSE: 0.980310
# Mean Absolute Error): 0.80
# Done with XGBoost for Alfotbreen using Sequential. Selected predictors:    u10  ssrd
# 0  u10  ssrd
#      -> Selector method: TreeBased
# 2 : optimal number of predictors and selected variables are Index(['tp', 'u10'], dtype='object')
# R² (Coefficient of determinaiton): -0.46
# RMSE: 0.805939
# Mean Absolute Error): 0.71
# Done with XGBoost for Alfotbreen using TreeBased. Selected predictors:    tp  u10
# 0  tp  u10
#
# --- Running Regressor: BayesianRidge ===
# Alfotbreen 61.75 5.65 1180.0
# Bw @ Alfotbreen: Missing months: 0
#      -> Selector method: Recursive
# 5 : optimal number of predictors and selected variables are Index(['tp', 'u10', 'v10', 'NAO', 'EA'], dtype='object')
# R² (Coefficient of determinaiton): 0.06
# RMSE: 0.645791
# Mean Absolute Error): 0.61
# Done with BayesianRidge for Alfotbreen using Recursive. Selected predictors:    tp  u10  v10  NAO  EA
# 0  tp  u10  v10  NAO  EA
#      -> Selector method: Sequential
# 2 : optimal number of predictors and selected variables are Index(['u10', 'ssrd'], dtype='object')
# R² (Coefficient of determinaiton): -0.36
# RMSE: 0.775760
# Mean Absolute Error): 0.69
# Done with BayesianRidge for Alfotbreen using Sequential. Selected predictors:    u10  ssrd
# 0  u10  ssrd
#      -> Selector method: TreeBased
# 2 : optimal number of predictors and selected variables are Index(['tp', 'u10'], dtype='object')
# R² (Coefficient of determinaiton): -0.34
# RMSE: 0.770848
# Mean Absolute Error): 0.67
# Done with BayesianRidge for Alfotbreen using TreeBased. Selected predictors:    tp  u10
# 0  tp  u10
#
# --- Processing Station: Austdalsbreen ---
#
# --- Running Regressor: RidgeCV ===
# Austdalsbreen 61.75 7.33 1470.0
# Bw @ Austdalsbreen: Missing months: 0
#      -> Selector method: Recursive
# 5 : optimal number of predictors and selected variables are Index(['tp', 'u10', 'v10', 'NAO', 'EA'], dtype='object')
# R² (Coefficient of determinaiton): 0.36
# RMSE: 0.562645
# Mean Absolute Error): 0.46
# Done with RidgeCV for Austdalsbreen using Recursive. Selected predictors:    tp  u10  v10  NAO  EA
# 0  tp  u10  v10  NAO  EA
#      -> Selector method: Sequential
# 2 : optimal number of predictors and selected variables are Index(['u10', 'NAO'], dtype='object')
# R² (Coefficient of determinaiton): -0.05
# RMSE: 0.722927
# Mean Absolute Error): 0.57
# Done with RidgeCV for Austdalsbreen using Sequential. Selected predictors:    u10  NAO
# 0  u10  NAO
#      -> Selector method: TreeBased
# 3 : optimal number of predictors and selected variables are Index(['tp', 'u10', 'v10'], dtype='object')
# R² (Coefficient of determinaiton): 0.65
# RMSE: 0.417752
# Mean Absolute Error): 0.35
# Done with RidgeCV for Austdalsbreen using TreeBased. Selected predictors:    tp  u10  v10
# 0  tp  u10  v10
#
# --- Running Regressor: Bagging ===
# Austdalsbreen 61.75 7.33 1470.0
# Bw @ Austdalsbreen: Missing months: 0
#      -> Selector method: Recursive
# 5 : optimal number of predictors and selected variables are Index(['tp', 'u10', 'v10', 'NAO', 'EA'], dtype='object')
# R² (Coefficient of determinaiton): 0.54
# RMSE: 0.478142
# Mean Absolute Error): 0.41
# Done with Bagging for Austdalsbreen using Recursive. Selected predictors:    tp  u10  v10  NAO  EA
# 0  tp  u10  v10  NAO  EA
#      -> Selector method: Sequential
# 2 : optimal number of predictors and selected variables are Index(['u10', 'NAO'], dtype='object')
# R² (Coefficient of determinaiton): -0.15
# RMSE: 0.754555
# Mean Absolute Error): 0.55
# Done with Bagging for Austdalsbreen using Sequential. Selected predictors:    u10  NAO
# 0  u10  NAO
#      -> Selector method: TreeBased
# 2 : optimal number of predictors and selected variables are Index(['tp', 'u10'], dtype='object')
# R² (Coefficient of determinaiton): 0.32
# RMSE: 0.578834
# Mean Absolute Error): 0.48
# Done with Bagging for Austdalsbreen using TreeBased. Selected predictors:    tp  u10
# 0  tp  u10
#
# --- Running Regressor: ARD ===
# Austdalsbreen 61.75 7.33 1470.0
# Bw @ Austdalsbreen: Missing months: 0
#      -> Selector method: Recursive
# 5 : optimal number of predictors and selected variables are Index(['tp', 'u10', 'v10', 'NAO', 'EA'], dtype='object')
# R² (Coefficient of determinaiton): 0.60
# RMSE: 0.443639
# Mean Absolute Error): 0.39
# Done with ARD for Austdalsbreen using Recursive. Selected predictors:    tp  u10  v10  NAO  EA
# 0  tp  u10  v10  NAO  EA
#      -> Selector method: Sequential
# 2 : optimal number of predictors and selected variables are Index(['u10', 'NAO'], dtype='object')
# R² (Coefficient of determinaiton): -0.01
# RMSE: 0.708229
# Mean Absolute Error): 0.55
# Done with ARD for Austdalsbreen using Sequential. Selected predictors:    u10  NAO
# 0  u10  NAO
#      -> Selector method: TreeBased
# 2 : optimal number of predictors and selected variables are Index(['tp', 'u10'], dtype='object')
# R² (Coefficient of determinaiton): 0.60
# RMSE: 0.444012
# Mean Absolute Error): 0.39
# Done with ARD for Austdalsbreen using TreeBased. Selected predictors:    tp  u10
# 0  tp  u10
#
# --- Running Regressor: RandomForest ===
# Austdalsbreen 61.75 7.33 1470.0
# Bw @ Austdalsbreen: Missing months: 0
#      -> Selector method: Recursive
# 5 : optimal number of predictors and selected variables are Index(['tp', 'u10', 'v10', 'NAO', 'EA'], dtype='object')
# R² (Coefficient of determinaiton): 0.51
# RMSE: 0.493405
# Mean Absolute Error): 0.43
# Done with RandomForest for Austdalsbreen using Recursive. Selected predictors:    tp  u10  v10  NAO  EA
# 0  tp  u10  v10  NAO  EA
#      -> Selector method: Sequential
# 2 : optimal number of predictors and selected variables are Index(['u10', 'NAO'], dtype='object')
# R² (Coefficient of determinaiton): -0.18
# RMSE: 0.766302
# Mean Absolute Error): 0.55
# Done with RandomForest for Austdalsbreen using Sequential. Selected predictors:    u10  NAO
# 0  u10  NAO
#      -> Selector method: TreeBased
# 3 : optimal number of predictors and selected variables are Index(['tp', 'v10', 'ssrd'], dtype='object')
# R² (Coefficient of determinaiton): 0.48
# RMSE: 0.507500
# Mean Absolute Error): 0.45
# Done with RandomForest for Austdalsbreen using TreeBased. Selected predictors:    tp  v10  ssrd
# 0  tp  v10  ssrd
#
# --- Running Regressor: XGBoost ===
# Austdalsbreen 61.75 7.33 1470.0
# Bw @ Austdalsbreen: Missing months: 0
#      -> Selector method: Recursive
# 5 : optimal number of predictors and selected variables are Index(['tp', 'u10', 'v10', 'NAO', 'EA'], dtype='object')
# R² (Coefficient of determinaiton): 0.57
# RMSE: 0.461374
# Mean Absolute Error): 0.38
# Done with XGBoost for Austdalsbreen using Recursive. Selected predictors:    tp  u10  v10  NAO  EA
# 0  tp  u10  v10  NAO  EA
#      -> Selector method: Sequential
# 2 : optimal number of predictors and selected variables are Index(['u10', 'NAO'], dtype='object')
# R² (Coefficient of determinaiton): -0.30
# RMSE: 0.804172
# Mean Absolute Error): 0.62
# Done with XGBoost for Austdalsbreen using Sequential. Selected predictors:    u10  NAO
# 0  u10  NAO
#      -> Selector method: TreeBased
# 3 : optimal number of predictors and selected variables are Index(['tp', 'u10', 'ssrd'], dtype='object')
# R² (Coefficient of determinaiton): 0.25
# RMSE: 0.609661
# Mean Absolute Error): 0.48
# Done with XGBoost for Austdalsbreen using TreeBased. Selected predictors:    tp  u10  ssrd
# 0  tp  u10  ssrd
#
# --- Running Regressor: BayesianRidge ===
# Austdalsbreen 61.75 7.33 1470.0
# Bw @ Austdalsbreen: Missing months: 0
#      -> Selector method: Recursive
# 5 : optimal number of predictors and selected variables are Index(['tp', 'u10', 'v10', 'NAO', 'EA'], dtype='object')
# R² (Coefficient of determinaiton): 0.33
# RMSE: 0.578127
# Mean Absolute Error): 0.47
# Done with BayesianRidge for Austdalsbreen using Recursive. Selected predictors:    tp  u10  v10  NAO  EA
# 0  tp  u10  v10  NAO  EA
#      -> Selector method: Sequential
# 2 : optimal number of predictors and selected variables are Index(['u10', 'NAO'], dtype='object')
# R² (Coefficient of determinaiton): -0.05
# RMSE: 0.721323
# Mean Absolute Error): 0.57
# Done with BayesianRidge for Austdalsbreen using Sequential. Selected predictors:    u10  NAO
# 0  u10  NAO
#      -> Selector method: TreeBased
# 3 : optimal number of predictors and selected variables are Index(['tp', 'u10', 'v10'], dtype='object')
# R² (Coefficient of determinaiton): 0.61
# RMSE: 0.440307
# Mean Absolute Error): 0.36
# Done with BayesianRidge for Austdalsbreen using TreeBased. Selected predictors:    tp  u10  v10
# 0  tp  u10  v10
#
# --- Processing Station: Engabreen ---
#
# --- Running Regressor: RidgeCV ===
# Engabreen 66.65 13.85 850.0
# Bw @ Engabreen: Missing months: 0
#      -> Selector method: Recursive
# 6 : optimal number of predictors and selected variables are Index(['t2m', 'tp', 'u10', 'v10', 'ssrd', 'EA'], dtype='object')
# R² (Coefficient of determinaiton): 0.52
# RMSE: 0.558016
# Mean Absolute Error): 0.52
# Done with RidgeCV for Engabreen using Recursive. Selected predictors:    t2m  tp  u10  v10  ssrd  EA
# 0  t2m  tp  u10  v10  ssrd  EA
#      -> Selector method: Sequential
# 2 : optimal number of predictors and selected variables are Index(['tp', 'u10'], dtype='object')
# R² (Coefficient of determinaiton): 0.43
# RMSE: 0.610555
# Mean Absolute Error): 0.53
# Done with RidgeCV for Engabreen using Sequential. Selected predictors:    tp  u10
# 0  tp  u10
#      -> Selector method: TreeBased
# 3 : optimal number of predictors and selected variables are Index(['t2m', 'tp', 'u10'], dtype='object')
# R² (Coefficient of determinaiton): 0.47
# RMSE: 0.590851
# Mean Absolute Error): 0.52
# Done with RidgeCV for Engabreen using TreeBased. Selected predictors:    t2m  tp  u10
# 0  t2m  tp  u10
#
# --- Running Regressor: Bagging ===
# Engabreen 66.65 13.85 850.0
# Bw @ Engabreen: Missing months: 0
#      -> Selector method: Recursive
# 6 : optimal number of predictors and selected variables are Index(['t2m', 'tp', 'u10', 'v10', 'ssrd', 'EA'], dtype='object')
# R² (Coefficient of determinaiton): 0.32
# RMSE: 0.668589
# Mean Absolute Error): 0.53
# Done with Bagging for Engabreen using Recursive. Selected predictors:    t2m  tp  u10  v10  ssrd  EA
# 0  t2m  tp  u10  v10  ssrd  EA
#      -> Selector method: Sequential
# 2 : optimal number of predictors and selected variables are Index(['tp', 'u10'], dtype='object')
# R² (Coefficient of determinaiton): -0.10
# RMSE: 0.848958
# Mean Absolute Error): 0.70
# Done with Bagging for Engabreen using Sequential. Selected predictors:    tp  u10
# 0  tp  u10
#      -> Selector method: TreeBased
# 2 : optimal number of predictors and selected variables are Index(['tp', 'u10'], dtype='object')
# R² (Coefficient of determinaiton): -0.10
# RMSE: 0.848958
# Mean Absolute Error): 0.70
# Done with Bagging for Engabreen using TreeBased. Selected predictors:    tp  u10
# 0  tp  u10
#
# --- Running Regressor: ARD ===
# Engabreen 66.65 13.85 850.0
# Bw @ Engabreen: Missing months: 0
#      -> Selector method: Recursive
# 6 : optimal number of predictors and selected variables are Index(['t2m', 'tp', 'u10', 'v10', 'ssrd', 'EA'], dtype='object')
# R² (Coefficient of determinaiton): 0.57
# RMSE: 0.528838
# Mean Absolute Error): 0.44
# Done with ARD for Engabreen using Recursive. Selected predictors:    t2m  tp  u10  v10  ssrd  EA
# 0  t2m  tp  u10  v10  ssrd  EA
#      -> Selector method: Sequential
# 2 : optimal number of predictors and selected variables are Index(['tp', 'u10'], dtype='object')
# R² (Coefficient of determinaiton): 0.57
# RMSE: 0.528938
# Mean Absolute Error): 0.44
# Done with ARD for Engabreen using Sequential. Selected predictors:    tp  u10
# 0  tp  u10
#      -> Selector method: TreeBased
# 2 : optimal number of predictors and selected variables are Index(['tp', 'u10'], dtype='object')
# R² (Coefficient of determinaiton): 0.57
# RMSE: 0.528938
# Mean Absolute Error): 0.44
# Done with ARD for Engabreen using TreeBased. Selected predictors:    tp  u10
# 0  tp  u10
#
# --- Running Regressor: RandomForest ===
# Engabreen 66.65 13.85 850.0
# Bw @ Engabreen: Missing months: 0
#      -> Selector method: Recursive
# 6 : optimal number of predictors and selected variables are Index(['t2m', 'tp', 'u10', 'v10', 'ssrd', 'EA'], dtype='object')
# R² (Coefficient of determinaiton): 0.29
# RMSE: 0.680126
# Mean Absolute Error): 0.55
# Done with RandomForest for Engabreen using Recursive. Selected predictors:    t2m  tp  u10  v10  ssrd  EA
# 0  t2m  tp  u10  v10  ssrd  EA
#      -> Selector method: Sequential
# 2 : optimal number of predictors and selected variables are Index(['tp', 'u10'], dtype='object')
# R² (Coefficient of determinaiton): -0.10
# RMSE: 0.848165
# Mean Absolute Error): 0.69
# Done with RandomForest for Engabreen using Sequential. Selected predictors:    tp  u10
# 0  tp  u10
#      -> Selector method: TreeBased
# 3 : optimal number of predictors and selected variables are Index(['t2m', 'tp', 'u10'], dtype='object')
# R² (Coefficient of determinaiton): 0.13
# RMSE: 0.753534
# Mean Absolute Error): 0.61
# Done with RandomForest for Engabreen using TreeBased. Selected predictors:    t2m  tp  u10
# 0  t2m  tp  u10
#
# --- Running Regressor: XGBoost ===
# Engabreen 66.65 13.85 850.0
# Bw @ Engabreen: Missing months: 0
#      -> Selector method: Recursive
# 6 : optimal number of predictors and selected variables are Index(['t2m', 'tp', 'u10', 'v10', 'ssrd', 'EA'], dtype='object')
# R² (Coefficient of determinaiton): -0.05
# RMSE: 0.826602
# Mean Absolute Error): 0.68
# Done with XGBoost for Engabreen using Recursive. Selected predictors:    t2m  tp  u10  v10  ssrd  EA
# 0  t2m  tp  u10  v10  ssrd  EA
#      -> Selector method: Sequential
# 2 : optimal number of predictors and selected variables are Index(['tp', 'u10'], dtype='object')
# R² (Coefficient of determinaiton): -0.46
# RMSE: 0.977139
# Mean Absolute Error): 0.86
# Done with XGBoost for Engabreen using Sequential. Selected predictors:    tp  u10
# 0  tp  u10
#      -> Selector method: TreeBased
# 2 : optimal number of predictors and selected variables are Index(['tp', 'u10'], dtype='object')
# R² (Coefficient of determinaiton): -0.46
# RMSE: 0.977139
# Mean Absolute Error): 0.86
# Done with XGBoost for Engabreen using TreeBased. Selected predictors:    tp  u10
# 0  tp  u10
#
# --- Running Regressor: BayesianRidge ===
# Engabreen 66.65 13.85 850.0
# Bw @ Engabreen: Missing months: 0
#      -> Selector method: Recursive
# 6 : optimal number of predictors and selected variables are Index(['t2m', 'tp', 'u10', 'v10', 'ssrd', 'EA'], dtype='object')
# R² (Coefficient of determinaiton): 0.45
# RMSE: 0.597950
# Mean Absolute Error): 0.54
# Done with BayesianRidge for Engabreen using Recursive. Selected predictors:    t2m  tp  u10  v10  ssrd  EA
# 0  t2m  tp  u10  v10  ssrd  EA
#      -> Selector method: Sequential
# 2 : optimal number of predictors and selected variables are Index(['tp', 'u10'], dtype='object')
# R² (Coefficient of determinaiton): 0.43
# RMSE: 0.610032
# Mean Absolute Error): 0.54
# Done with BayesianRidge for Engabreen using Sequential. Selected predictors:    tp  u10
# 0  tp  u10
#      -> Selector method: TreeBased
# 3 : optimal number of predictors and selected variables are Index(['t2m', 'tp', 'u10'], dtype='object')
# R² (Coefficient of determinaiton): 0.47
# RMSE: 0.590735
# Mean Absolute Error): 0.54
# Done with BayesianRidge for Engabreen using TreeBased. Selected predictors:    t2m  tp  u10
# 0  t2m  tp  u10
#
# --- Processing Station: Grafjellsbrea ---
#
# --- Running Regressor: RidgeCV ===
# Grafjellsbrea 60.1 6.38 1320.0
# Bw @ Grafjellsbrea: Missing months: 0
#      -> Selector method: Recursive
# 7 : optimal number of predictors and selected variables are Index(['t2m', 'tp', 'u10', 'v10', 'ssrd', 'NAO', 'EA'], dtype='object')
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_search.py:1108: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan]
#   warnings.warn(
# R² (Coefficient of determinaiton): -0.13
# RMSE: 1.535967
# Mean Absolute Error): 1.30
# Done with RidgeCV for Grafjellsbrea using Recursive. Selected predictors:    t2m  tp  u10  v10  ssrd  NAO  EA
# 0  t2m  tp  u10  v10  ssrd  NAO  EA
#      -> Selector method: Sequential
# 2 : optimal number of predictors and selected variables are Index(['t2m', 'tp'], dtype='object')
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_search.py:1108: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan]
#   warnings.warn(
# R² (Coefficient of determinaiton): 0.08
# RMSE: 1.384945
# Mean Absolute Error): 0.99
# Done with RidgeCV for Grafjellsbrea using Sequential. Selected predictors:    t2m  tp
# 0  t2m  tp
#      -> Selector method: TreeBased
# 2 : optimal number of predictors and selected variables are Index(['tp', 'u10'], dtype='object')
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\danis\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_search.py:1108: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan]
#   warnings.warn(
# R² (Coefficient of determinaiton): 0.32
# RMSE: 1.193072
# Mean Absolute Error): 0.84
# Done with RidgeCV for Grafjellsbrea using TreeBased. Selected predictors:    tp  u10
# 0  tp  u10
#
# --- Running Regressor: Bagging ===
# Grafjellsbrea 60.1 6.38 1320.0
# Bw @ Grafjellsbrea: Missing months: 0
#      -> Selector method: Recursive
# 7 : optimal number of predictors and selected variables are Index(['t2m', 'tp', 'u10', 'v10', 'ssrd', 'NAO', 'EA'], dtype='object')
# R² (Coefficient of determinaiton): 0.18
# RMSE: 1.307361
# Mean Absolute Error): 0.88
# Done with Bagging for Grafjellsbrea using Recursive. Selected predictors:    t2m  tp  u10  v10  ssrd  NAO  EA
# 0  t2m  tp  u10  v10  ssrd  NAO  EA
#      -> Selector method: Sequential
# 2 : optimal number of predictors and selected variables are Index(['t2m', 'tp'], dtype='object')
# R² (Coefficient of determinaiton): 0.32
# RMSE: 1.185679
# Mean Absolute Error): 0.91
# Done with Bagging for Grafjellsbrea using Sequential. Selected predictors:    t2m  tp
# 0  t2m  tp
#      -> Selector method: TreeBased
# 2 : optimal number of predictors and selected variables are Index(['tp', 'u10'], dtype='object')
# R² (Coefficient of determinaiton): 0.45
# RMSE: 1.067229
# Mean Absolute Error): 0.80
# Done with Bagging for Grafjellsbrea using TreeBased. Selected predictors:    tp  u10
# 0  tp  u10
#
# --- Running Regressor: ARD ===
# Grafjellsbrea 60.1 6.38 1320.0
# Bw @ Grafjellsbrea: Missing months: 0
#      -> Selector method: Recursive
# 7 : optimal number of predictors and selected variables are Index(['t2m', 'tp', 'u10', 'v10', 'ssrd', 'NAO', 'EA'], dtype='object')
# R² (Coefficient of determinaiton): 0.34
# RMSE: 1.171159
# Mean Absolute Error): 0.79
# Done with ARD for Grafjellsbrea using Recursive. Selected predictors:    t2m  tp  u10  v10  ssrd  NAO  EA
# 0  t2m  tp  u10  v10  ssrd  NAO  EA
#      -> Selector method: Sequential
# 2 : optimal number of predictors and selected variables are Index(['t2m', 'tp'], dtype='object')
# R² (Coefficient of determinaiton): 0.34
# RMSE: 1.172596
# Mean Absolute Error): 0.79
# Done with ARD for Grafjellsbrea using Sequential. Selected predictors:    t2m  tp
# 0  t2m  tp
#      -> Selector method: TreeBased
# 2 : optimal number of predictors and selected variables are Index(['tp', 'u10'], dtype='object')
# R² (Coefficient of determinaiton): 0.34
# RMSE: 1.172508
# Mean Absolute Error): 0.79
# Done with ARD for Grafjellsbrea using TreeBased. Selected predictors:    tp  u10
# 0  tp  u10
#
# --- Running Regressor: RandomForest ===
# Grafjellsbrea 60.1 6.38 1320.0
# Bw @ Grafjellsbrea: Missing months: 0
#      -> Selector method: Recursive
# 7 : optimal number of predictors and selected variables are Index(['t2m', 'tp', 'u10', 'v10', 'ssrd', 'NAO', 'EA'], dtype='object')
# R² (Coefficient of determinaiton): 0.20
# RMSE: 1.291157
# Mean Absolute Error): 0.89
# Done with RandomForest for Grafjellsbrea using Recursive. Selected predictors:    t2m  tp  u10  v10  ssrd  NAO  EA
# 0  t2m  tp  u10  v10  ssrd  NAO  EA
#      -> Selector method: Sequential
# 2 : optimal number of predictors and selected variables are Index(['t2m', 'tp'], dtype='object')
# R² (Coefficient of determinaiton): 0.31
# RMSE: 1.199621
# Mean Absolute Error): 0.92
# Done with RandomForest for Grafjellsbrea using Sequential. Selected predictors:    t2m  tp
# 0  t2m  tp
#      -> Selector method: TreeBased
# 2 : optimal number of predictors and selected variables are Index(['tp', 'u10'], dtype='object')
# R² (Coefficient of determinaiton): 0.46
# RMSE: 1.059707
# Mean Absolute Error): 0.80
# Done with RandomForest for Grafjellsbrea using TreeBased. Selected predictors:    tp  u10
# 0  tp  u10
#
# --- Running Regressor: XGBoost ===
# Grafjellsbrea 60.1 6.38 1320.0
# Bw @ Grafjellsbrea: Missing months: 0
#      -> Selector method: Recursive
# 7 : optimal number of predictors and selected variables are Index(['t2m', 'tp', 'u10', 'v10', 'ssrd', 'NAO', 'EA'], dtype='object')
# R² (Coefficient of determinaiton): 0.30
# RMSE: 1.202679
# Mean Absolute Error): 0.93
# Done with XGBoost for Grafjellsbrea using Recursive. Selected predictors:    t2m  tp  u10  v10  ssrd  NAO  EA
# 0  t2m  tp  u10  v10  ssrd  NAO  EA
#      -> Selector method: Sequential
# 2 : optimal number of predictors and selected variables are Index(['t2m', 'tp'], dtype='object')
# R² (Coefficient of determinaiton): 0.11
# RMSE: 1.364765
# Mean Absolute Error): 1.22
# Done with XGBoost for Grafjellsbrea using Sequential. Selected predictors:    t2m  tp
# 0  t2m  tp
#      -> Selector method: TreeBased
# 3 : optimal number of predictors and selected variables are Index(['tp', 'u10', 'v10'], dtype='object')
# R² (Coefficient of determinaiton): 0.40
# RMSE: 1.114877
# Mean Absolute Error): 0.87
# Done with XGBoost for Grafjellsbrea using TreeBased. Selected predictors:    tp  u10  v10
# 0  tp  u10  v10
#
# --- Running Regressor: BayesianRidge ===
# Grafjellsbrea 60.1 6.38 1320.0
# Bw @ Grafjellsbrea: Missing months: 0
#      -> Selector method: Recursive
# 7 : optimal number of predictors and selected variables are Index(['t2m', 'tp', 'u10', 'v10', 'ssrd', 'NAO', 'EA'], dtype='object')
# R² (Coefficient of determinaiton): 0.08
# RMSE: 1.385392
# Mean Absolute Error): 1.11
# Done with BayesianRidge for Grafjellsbrea using Recursive. Selected predictors:    t2m  tp  u10  v10  ssrd  NAO  EA
# 0  t2m  tp  u10  v10  ssrd  NAO  EA
#      -> Selector method: Sequential
# 2 : optimal number of predictors and selected variables are Index(['t2m', 'tp'], dtype='object')
# R² (Coefficient of determinaiton): 0.03
# RMSE: 1.421973
# Mean Absolute Error): 1.04
# Done with BayesianRidge for Grafjellsbrea using Sequential. Selected predictors:    t2m  tp
# 0  t2m  tp
#      -> Selector method: TreeBased
# 3 : optimal number of predictors and selected variables are Index(['tp', 'u10', 'NAO'], dtype='object')
# R² (Coefficient of determinaiton): 0.15
# RMSE: 1.326855
# Mean Absolute Error): 0.94
# Done with BayesianRidge for Grafjellsbrea using TreeBased. Selected predictors:    tp  u10  NAO
# 0  tp  u10  NAO
#
# --- Processing Station: Grasubreen ---
#
# --- Running Regressor: RidgeCV ===
# Grasubreen 61.65 8.62 2065.0
# Bw @ Grasubreen: Missing months: 0
#      -> Selector method: Recursive
# 6 : optimal number of predictors and selected variables are Index(['tp', 'u10', 'v10', 'ssrd', 'NAO', 'EA'], dtype='object')
# R² (Coefficient of determinaiton): -0.22
# RMSE: 0.854477
# Mean Absolute Error): 0.66
# Done with RidgeCV for Grasubreen using Recursive. Selected predictors:    tp  u10  v10  ssrd  NAO  EA
# 0  tp  u10  v10  ssrd  NAO  EA
#      -> Selector method: Sequential
# 2 : optimal number of predictors and selected variables are Index(['tp', 'NAO'], dtype='object')
# R² (Coefficient of determinaiton): -0.46
# RMSE: 0.933008
# Mean Absolute Error): 0.77
# Done with RidgeCV for Grasubreen using Sequential. Selected predictors:    tp  NAO
# 0  tp  NAO
#      -> Selector method: TreeBased
# 4 : optimal number of predictors and selected variables are Index(['tp', 'v10', 'ssrd', 'EA'], dtype='object')
# R² (Coefficient of determinaiton): -0.04
# RMSE: 0.787895
# Mean Absolute Error): 0.61
# Done with RidgeCV for Grasubreen using TreeBased. Selected predictors:    tp  v10  ssrd  EA
# 0  tp  v10  ssrd  EA
#
# --- Running Regressor: Bagging ===
# Grasubreen 61.65 8.62 2065.0
# Bw @ Grasubreen: Missing months: 0
#      -> Selector method: Recursive
# 6 : optimal number of predictors and selected variables are Index(['tp', 'u10', 'v10', 'ssrd', 'NAO', 'EA'], dtype='object')
# R² (Coefficient of determinaiton): -0.02
# RMSE: 0.781793
# Mean Absolute Error): 0.59
# Done with Bagging for Grasubreen using Recursive. Selected predictors:    tp  u10  v10  ssrd  NAO  EA
# 0  tp  u10  v10  ssrd  NAO  EA
#      -> Selector method: Sequential
# 2 : optimal number of predictors and selected variables are Index(['tp', 'NAO'], dtype='object')
# R² (Coefficient of determinaiton): -0.37
# RMSE: 0.904360
# Mean Absolute Error): 0.69
# Done with Bagging for Grasubreen using Sequential. Selected predictors:    tp  NAO
# 0  tp  NAO
#      -> Selector method: TreeBased
# 3 : optimal number of predictors and selected variables are Index(['tp', 'v10', 'ssrd'], dtype='object')
# R² (Coefficient of determinaiton): 0.06
# RMSE: 0.748741
# Mean Absolute Error): 0.58
# Done with Bagging for Grasubreen using TreeBased. Selected predictors:    tp  v10  ssrd
# 0  tp  v10  ssrd
#
# --- Running Regressor: ARD ===
# Grasubreen 61.65 8.62 2065.0
# Bw @ Grasubreen: Missing months: 0
#      -> Selector method: Recursive
# 6 : optimal number of predictors and selected variables are Index(['tp', 'u10', 'v10', 'ssrd', 'NAO', 'EA'], dtype='object')
# R² (Coefficient of determinaiton): -0.21
# RMSE: 0.850634
# Mean Absolute Error): 0.70
# Done with ARD for Grasubreen using Recursive. Selected predictors:    tp  u10  v10  ssrd  NAO  EA
# 0  tp  u10  v10  ssrd  NAO  EA
#      -> Selector method: Sequential
# ...
# R² (Coefficient of determinaiton): 0.44
# RMSE: 0.619735
# Mean Absolute Error): 0.51
# Done with RandomForest for Nigardsbreen using TreeBased. Selected predictors:    tp  u10
# 0  tp  u10
#
# --- Running Regressor: XGBoost ===
# Nigardsbreen 61.69 7.2 1136.0
# Bw @ Nigardsbreen: Missing months: 0
#      -> Selector method: Recursive
# 7 : optimal number of predictors and selected variables are Index(['t2m', 'tp', 'u10', 'v10', 'ssrd', 'NAO', 'EA'], dtype='object')
# R² (Coefficient of determinaiton): 0.18
# RMSE: 0.752747
# Mean Absolute Error): 0.54
# Done with XGBoost for Nigardsbreen using Recursive. Selected predictors:    t2m  tp  u10  v10  ssrd  NAO  EA
# 0  t2m  tp  u10  v10  ssrd  NAO  EA
#      -> Selector method: Sequential
# 2 : optimal number of predictors and selected variables are Index(['u10', 'ssrd'], dtype='object')
# R² (Coefficient of determinaiton): -0.63
# RMSE: 1.062545
# Mean Absolute Error): 0.90
# Done with XGBoost for Nigardsbreen using Sequential. Selected predictors:    u10  ssrd
# 0  u10  ssrd
#      -> Selector method: TreeBased
# 2 : optimal number of predictors and selected variables are Index(['tp', 'u10'], dtype='object')
# R² (Coefficient of determinaiton): -0.09
# RMSE: 0.869267
# Mean Absolute Error): 0.74
# Done with XGBoost for Nigardsbreen using TreeBased. Selected predictors:    tp  u10
# 0  tp  u10
#
# --- Running Regressor: BayesianRidge ===
# Nigardsbreen 61.69 7.2 1136.0
# Bw @ Nigardsbreen: Missing months: 0
#      -> Selector method: Recursive
# 7 : optimal number of predictors and selected variables are Index(['t2m', 'tp', 'u10', 'v10', 'ssrd', 'NAO', 'EA'], dtype='object')
# R² (Coefficient of determinaiton): 0.34
# RMSE: 0.677427
# Mean Absolute Error): 0.60
# Done with BayesianRidge for Nigardsbreen using Recursive. Selected predictors:    t2m  tp  u10  v10  ssrd  NAO  EA
# 0  t2m  tp  u10  v10  ssrd  NAO  EA
#      -> Selector method: Sequential
# 2 : optimal number of predictors and selected variables are Index(['u10', 'ssrd'], dtype='object')
# R² (Coefficient of determinaiton): 0.01
# RMSE: 0.827250
# Mean Absolute Error): 0.69
# Done with BayesianRidge for Nigardsbreen using Sequential. Selected predictors:    u10  ssrd
# 0  u10  ssrd
#      -> Selector method: TreeBased
# 2 : optimal number of predictors and selected variables are Index(['tp', 'u10'], dtype='object')
# R² (Coefficient of determinaiton): -0.10
# RMSE: 0.873453
# Mean Absolute Error): 0.73
# Done with BayesianRidge for Nigardsbreen using TreeBased. Selected predictors:    tp  u10
# 0  tp  u10
#
# --- Processing Station: Rembesdalskaka ---
#
# --- Running Regressor: RidgeCV ===
# Rembesdalskaka 60.54 7.37 1450.0
# Bw @ Rembesdalskaka: Missing months: 0
#      -> Selector method: Recursive
# 6 : optimal number of predictors and selected variables are Index(['t2m', 'tp', 'u10', 'v10', 'ssrd', 'EA'], dtype='object')
# R² (Coefficient of determinaiton): 0.60
# RMSE: 0.409622
# Mean Absolute Error): 0.35
# Done with RidgeCV for Rembesdalskaka using Recursive. Selected predictors:    t2m  tp  u10  v10  ssrd  EA
# 0  t2m  tp  u10  v10  ssrd  EA
#      -> Selector method: Sequential
# 2 : optimal number of predictors and selected variables are Index(['u10', 'ssrd'], dtype='object')
# R² (Coefficient of determinaiton): 0.40
# RMSE: 0.500840
# Mean Absolute Error): 0.42
# Done with RidgeCV for Rembesdalskaka using Sequential. Selected predictors:    u10  ssrd
# 0  u10  ssrd
#      -> Selector method: TreeBased
# 2 : optimal number of predictors and selected variables are Index(['tp', 'u10'], dtype='object')
# R² (Coefficient of determinaiton): 0.19
# RMSE: 0.581416
# Mean Absolute Error): 0.42
# Done with RidgeCV for Rembesdalskaka using TreeBased. Selected predictors:    tp  u10
# 0  tp  u10
#
# --- Running Regressor: Bagging ===
# Rembesdalskaka 60.54 7.37 1450.0
# Bw @ Rembesdalskaka: Missing months: 0
#      -> Selector method: Recursive
# 6 : optimal number of predictors and selected variables are Index(['t2m', 'tp', 'u10', 'v10', 'ssrd', 'EA'], dtype='object')
# R² (Coefficient of determinaiton): 0.45
# RMSE: 0.479750
# Mean Absolute Error): 0.39
# Done with Bagging for Rembesdalskaka using Recursive. Selected predictors:    t2m  tp  u10  v10  ssrd  EA
# 0  t2m  tp  u10  v10  ssrd  EA
#      -> Selector method: Sequential
# 2 : optimal number of predictors and selected variables are Index(['u10', 'ssrd'], dtype='object')
# R² (Coefficient of determinaiton): 0.47
# RMSE: 0.469972
# Mean Absolute Error): 0.38
# Done with Bagging for Rembesdalskaka using Sequential. Selected predictors:    u10  ssrd
# 0  u10  ssrd
#      -> Selector method: TreeBased
# 2 : optimal number of predictors and selected variables are Index(['tp', 'u10'], dtype='object')
# R² (Coefficient of determinaiton): 0.32
# RMSE: 0.531826
# Mean Absolute Error): 0.41
# Done with Bagging for Rembesdalskaka using TreeBased. Selected predictors:    tp  u10
# 0  tp  u10
#
# --- Running Regressor: ARD ===
# Rembesdalskaka 60.54 7.37 1450.0
# Bw @ Rembesdalskaka: Missing months: 0
#      -> Selector method: Recursive
# 6 : optimal number of predictors and selected variables are Index(['t2m', 'tp', 'u10', 'v10', 'ssrd', 'EA'], dtype='object')
# R² (Coefficient of determinaiton): 0.69
# RMSE: 0.361882
# Mean Absolute Error): 0.31
# Done with ARD for Rembesdalskaka using Recursive. Selected predictors:    t2m  tp  u10  v10  ssrd  EA
# 0  t2m  tp  u10  v10  ssrd  EA
#      -> Selector method: Sequential
# 2 : optimal number of predictors and selected variables are Index(['u10', 'ssrd'], dtype='object')
# R² (Coefficient of determinaiton): 0.15
# RMSE: 0.595770
# Mean Absolute Error): 0.43
# Done with ARD for Rembesdalskaka using Sequential. Selected predictors:    u10  ssrd
# 0  u10  ssrd
#      -> Selector method: TreeBased
# 2 : optimal number of predictors and selected variables are Index(['tp', 'u10'], dtype='object')
# R² (Coefficient of determinaiton): 0.79
# RMSE: 0.295644
# Mean Absolute Error): 0.25
# Done with ARD for Rembesdalskaka using TreeBased. Selected predictors:    tp  u10
# 0  tp  u10
#
# --- Running Regressor: RandomForest ===
# Rembesdalskaka 60.54 7.37 1450.0
# Bw @ Rembesdalskaka: Missing months: 0
#      -> Selector method: Recursive
# 6 : optimal number of predictors and selected variables are Index(['t2m', 'tp', 'u10', 'v10', 'ssrd', 'EA'], dtype='object')
# R² (Coefficient of determinaiton): 0.41
# RMSE: 0.494783
# Mean Absolute Error): 0.39
# Done with RandomForest for Rembesdalskaka using Recursive. Selected predictors:    t2m  tp  u10  v10  ssrd  EA
# 0  t2m  tp  u10  v10  ssrd  EA
#      -> Selector method: Sequential
# 2 : optimal number of predictors and selected variables are Index(['u10', 'ssrd'], dtype='object')
# R² (Coefficient of determinaiton): 0.49
# RMSE: 0.461684
# Mean Absolute Error): 0.37
# Done with RandomForest for Rembesdalskaka using Sequential. Selected predictors:    u10  ssrd
# 0  u10  ssrd
#      -> Selector method: TreeBased
# 2 : optimal number of predictors and selected variables are Index(['tp', 'u10'], dtype='object')
# R² (Coefficient of determinaiton): 0.34
# RMSE: 0.524649
# Mean Absolute Error): 0.39
# Done with RandomForest for Rembesdalskaka using TreeBased. Selected predictors:    tp  u10
# 0  tp  u10
#
# --- Running Regressor: XGBoost ===
# Rembesdalskaka 60.54 7.37 1450.0
# Bw @ Rembesdalskaka: Missing months: 0
#      -> Selector method: Recursive
# 6 : optimal number of predictors and selected variables are Index(['t2m', 'tp', 'u10', 'v10', 'ssrd', 'EA'], dtype='object')
# R² (Coefficient of determinaiton): 0.30
# RMSE: 0.541214
# Mean Absolute Error): 0.46
# Done with XGBoost for Rembesdalskaka using Recursive. Selected predictors:    t2m  tp  u10  v10  ssrd  EA
# 0  t2m  tp  u10  v10  ssrd  EA
#      -> Selector method: Sequential
# 2 : optimal number of predictors and selected variables are Index(['u10', 'ssrd'], dtype='object')
# R² (Coefficient of determinaiton): -0.39
# RMSE: 0.762392
# Mean Absolute Error): 0.65
# Done with XGBoost for Rembesdalskaka using Sequential. Selected predictors:    u10  ssrd
# 0  u10  ssrd
#      -> Selector method: TreeBased
# 2 : optimal number of predictors and selected variables are Index(['tp', 'u10'], dtype='object')
# R² (Coefficient of determinaiton): -0.04
# RMSE: 0.657902
# Mean Absolute Error): 0.54
# Done with XGBoost for Rembesdalskaka using TreeBased. Selected predictors:    tp  u10
# 0  tp  u10
#
# --- Running Regressor: BayesianRidge ===
# Rembesdalskaka 60.54 7.37 1450.0
# Bw @ Rembesdalskaka: Missing months: 0
#      -> Selector method: Recursive
# 6 : optimal number of predictors and selected variables are Index(['t2m', 'tp', 'u10', 'v10', 'ssrd', 'EA'], dtype='object')
# R² (Coefficient of determinaiton): 0.66
# RMSE: 0.374482
# Mean Absolute Error): 0.31
# Done with BayesianRidge for Rembesdalskaka using Recursive. Selected predictors:    t2m  tp  u10  v10  ssrd  EA
# 0  t2m  tp  u10  v10  ssrd  EA
#      -> Selector method: Sequential
# 2 : optimal number of predictors and selected variables are Index(['u10', 'ssrd'], dtype='object')
# R² (Coefficient of determinaiton): 0.39
# RMSE: 0.504862
# Mean Absolute Error): 0.42
# Done with BayesianRidge for Rembesdalskaka using Sequential. Selected predictors:    u10  ssrd
# 0  u10  ssrd
#      -> Selector method: TreeBased
# 2 : optimal number of predictors and selected variables are Index(['tp', 'u10'], dtype='object')
# R² (Coefficient of determinaiton): 0.15
# RMSE: 0.595717
# Mean Absolute Error): 0.43
# Done with BayesianRidge for Rembesdalskaka using TreeBased. Selected predictors:    tp  u10
# 0  tp  u10
#
# --- Processing Station: Storbreen ---
#
# --- Running Regressor: RidgeCV ===
# Storebreen 61.57 8.13 1700.0
# Bw @ Storbreen: Missing months: 0
#      -> Selector method: Recursive
# 7 : optimal number of predictors and selected variables are Index(['t2m', 'tp', 'u10', 'v10', 'ssrd', 'NAO', 'EA'], dtype='object')
# R² (Coefficient of determinaiton): 0.24
# RMSE: 0.652772
# Mean Absolute Error): 0.58
# Done with RidgeCV for Storbreen using Recursive. Selected predictors:    t2m  tp  u10  v10  ssrd  NAO  EA
# 0  t2m  tp  u10  v10  ssrd  NAO  EA
#      -> Selector method: Sequential
# 2 : optimal number of predictors and selected variables are Index(['u10', 'v10'], dtype='object')
# R² (Coefficient of determinaiton): 0.20
# RMSE: 0.667816
# Mean Absolute Error): 0.62
# Done with RidgeCV for Storbreen using Sequential. Selected predictors:    u10  v10
# 0  u10  v10
#      -> Selector method: TreeBased
# 2 : optimal number of predictors and selected variables are Index(['tp', 'v10'], dtype='object')
# R² (Coefficient of determinaiton): 0.26
# RMSE: 0.643209
# Mean Absolute Error): 0.48
# Done with RidgeCV for Storbreen using TreeBased. Selected predictors:    tp  v10
# 0  tp  v10
#
# --- Running Regressor: Bagging ===
# Storebreen 61.57 8.13 1700.0
# Bw @ Storbreen: Missing months: 0
#      -> Selector method: Recursive
# 7 : optimal number of predictors and selected variables are Index(['t2m', 'tp', 'u10', 'v10', 'ssrd', 'NAO', 'EA'], dtype='object')
# R² (Coefficient of determinaiton): 0.31
# RMSE: 0.620500
# Mean Absolute Error): 0.50
# Done with Bagging for Storbreen using Recursive. Selected predictors:    t2m  tp  u10  v10  ssrd  NAO  EA
# 0  t2m  tp  u10  v10  ssrd  NAO  EA
#      -> Selector method: Sequential
# 2 : optimal number of predictors and selected variables are Index(['u10', 'v10'], dtype='object')
# R² (Coefficient of determinaiton): 0.19
# RMSE: 0.671806
# Mean Absolute Error): 0.59
# Done with Bagging for Storbreen using Sequential. Selected predictors:    u10  v10
# 0  u10  v10
#      -> Selector method: TreeBased
# 2 : optimal number of predictors and selected variables are Index(['tp', 'v10'], dtype='object')
# R² (Coefficient of determinaiton): 0.13
# RMSE: 0.699108
# Mean Absolute Error): 0.53
# Done with Bagging for Storbreen using TreeBased. Selected predictors:    tp  v10
# 0  tp  v10
#
# --- Running Regressor: ARD ===
# Storebreen 61.57 8.13 1700.0
# Bw @ Storbreen: Missing months: 0
#      -> Selector method: Recursive
# 7 : optimal number of predictors and selected variables are Index(['t2m', 'tp', 'u10', 'v10', 'ssrd', 'NAO', 'EA'], dtype='object')
# R² (Coefficient of determinaiton): 0.29
# RMSE: 0.630568
# Mean Absolute Error): 0.52
# Done with ARD for Storbreen using Recursive. Selected predictors:    t2m  tp  u10  v10  ssrd  NAO  EA
# 0  t2m  tp  u10  v10  ssrd  NAO  EA
#      -> Selector method: Sequential
# 2 : optimal number of predictors and selected variables are Index(['u10', 'v10'], dtype='object')
# R² (Coefficient of determinaiton): 0.24
# RMSE: 0.650520
# Mean Absolute Error): 0.60
# Done with ARD for Storbreen using Sequential. Selected predictors:    u10  v10
# 0  u10  v10
#      -> Selector method: TreeBased
# 2 : optimal number of predictors and selected variables are Index(['tp', 'v10'], dtype='object')
# R² (Coefficient of determinaiton): 0.27
# RMSE: 0.638519
# Mean Absolute Error): 0.54
# Done with ARD for Storbreen using TreeBased. Selected predictors:    tp  v10
# 0  tp  v10
#
# --- Running Regressor: RandomForest ===
# Storebreen 61.57 8.13 1700.0
# Bw @ Storbreen: Missing months: 0
#      -> Selector method: Recursive
# 7 : optimal number of predictors and selected variables are Index(['t2m', 'tp', 'u10', 'v10', 'ssrd', 'NAO', 'EA'], dtype='object')
# R² (Coefficient of determinaiton): 0.31
# RMSE: 0.620052
# Mean Absolute Error): 0.50
# Done with RandomForest for Storbreen using Recursive. Selected predictors:    t2m  tp  u10  v10  ssrd  NAO  EA
# 0  t2m  tp  u10  v10  ssrd  NAO  EA
#      -> Selector method: Sequential
# 2 : optimal number of predictors and selected variables are Index(['u10', 'v10'], dtype='object')
# R² (Coefficient of determinaiton): 0.18
# RMSE: 0.677363
# Mean Absolute Error): 0.60
# Done with RandomForest for Storbreen using Sequential. Selected predictors:    u10  v10
# 0  u10  v10
#      -> Selector method: TreeBased
# 2 : optimal number of predictors and selected variables are Index(['tp', 'v10'], dtype='object')
# R² (Coefficient of determinaiton): 0.12
# RMSE: 0.703594
# Mean Absolute Error): 0.54
# Done with RandomForest for Storbreen using TreeBased. Selected predictors:    tp  v10
# 0  tp  v10
#
# --- Running Regressor: XGBoost ===
# Storebreen 61.57 8.13 1700.0
# Bw @ Storbreen: Missing months: 0
#      -> Selector method: Recursive
# 7 : optimal number of predictors and selected variables are Index(['t2m', 'tp', 'u10', 'v10', 'ssrd', 'NAO', 'EA'], dtype='object')
# R² (Coefficient of determinaiton): 0.44
# RMSE: 0.561610
# Mean Absolute Error): 0.43
# Done with XGBoost for Storbreen using Recursive. Selected predictors:    t2m  tp  u10  v10  ssrd  NAO  EA
# 0  t2m  tp  u10  v10  ssrd  NAO  EA
#      -> Selector method: Sequential
# 2 : optimal number of predictors and selected variables are Index(['u10', 'v10'], dtype='object')
# R² (Coefficient of determinaiton): -0.35
# RMSE: 0.867831
# Mean Absolute Error): 0.80
# Done with XGBoost for Storbreen using Sequential. Selected predictors:    u10  v10
# 0  u10  v10
#      -> Selector method: TreeBased
# 2 : optimal number of predictors and selected variables are Index(['tp', 'v10'], dtype='object')
# R² (Coefficient of determinaiton): -0.36
# RMSE: 0.873934
# Mean Absolute Error): 0.66
# Done with XGBoost for Storbreen using TreeBased. Selected predictors:    tp  v10
# 0  tp  v10
#
# --- Running Regressor: BayesianRidge ===
# Storebreen 61.57 8.13 1700.0
# Bw @ Storbreen: Missing months: 0
#      -> Selector method: Recursive
# 7 : optimal number of predictors and selected variables are Index(['t2m', 'tp', 'u10', 'v10', 'ssrd', 'NAO', 'EA'], dtype='object')
# R² (Coefficient of determinaiton): 0.26
# RMSE: 0.645260
# Mean Absolute Error): 0.59
# Done with BayesianRidge for Storbreen using Recursive. Selected predictors:    t2m  tp  u10  v10  ssrd  NAO  EA
# 0  t2m  tp  u10  v10  ssrd  NAO  EA
#      -> Selector method: Sequential
# 2 : optimal number of predictors and selected variables are Index(['u10', 'v10'], dtype='object')
# R² (Coefficient of determinaiton): 0.22
# RMSE: 0.661912
# Mean Absolute Error): 0.61
# Done with BayesianRidge for Storbreen using Sequential. Selected predictors:    u10  v10
# 0  u10  v10
#      -> Selector method: TreeBased
# 2 : optimal number of predictors and selected variables are Index(['tp', 'v10'], dtype='object')
# R² (Coefficient of determinaiton): 0.40
# RMSE: 0.577750
# Mean Absolute Error): 0.51
# Done with BayesianRidge for Storbreen using TreeBased. Selected predictors:    tp  v10
# 0  tp  v10

# %%
metrics_path = os.path.join(results_dir, "model_metrics_bw.csv")
results_df.to_csv(metrics_path, index=False)

# %%
# Load your updated CSV
metrics_path = os.path.join(results_dir, "model_metrics_bw.csv")
df = pd.read_csv(metrics_path)
#df= results_df

# Define custom colors for Selector methods
colors = {
    "Rec": "#ca0020",   # red
    "Seq": "#0571b0",  # blue
    "Tree": "#fdb863"    # orange-yellow
}

gridline_color = "#d3d3d3"
variables = ["Bw"]

for var in variables:
    fig, ax = plt.subplots(figsize=(15, 8))
    sns.boxplot(data=df[df["Variable"] == var], x="Regressor", y="R2", hue="Selector", palette=colors, ax=ax)

    ax.set_title(f"Test R² Scores for {var} (1950-2023)", fontsize=18, fontweight="bold")
    ax.set_ylabel("Test R²", fontsize=18, fontweight="bold")
    ax.set_xlabel("Regressor", fontsize=18, fontweight="bold")
    ax.grid(True, linestyle="--", color=gridline_color)
    ax.legend(title="Selector", title_fontsize=18, fontsize=18)
    ax.set_ylim(-1, 1)
    plt.xticks(rotation=45, size=18)
    plt.yticks(size=16)
    plt.tight_layout()
    #plt.savefig(f"boxplot_r2_{var}_complete.png", dpi=800, bbox_inches='tight')
    plt.show()

# %%
# Load results
results_df = pd.read_csv(r"C:\Users\danis\Desktop\Danish\Scripts_Python\Results\model_metrics_bw.csv")

# Create combined model column
results_df["Model"] = results_df["Regressor"] + " - " + results_df["Selector"]

# Pivot table
#pivot_df = results_df.pivot(index="Glacier", columns="Model", values="RMSE")
pivot_df = results_df.pivot_table(index="Glacier", columns="Model", values="RMSE", aggfunc="mean")

gridline_color = "#d3d3d3"  # light grey
plt.figure(figsize=(20, 10))
sns.heatmap(
    pivot_df,
    annot=True,
    fmt=".2f",
    cmap="RdYlBu_r",
    linewidths=0.5,
    linecolor=gridline_color,
    cbar_kws={'label': 'RMSE'},
    annot_kws={"fontsize": 16, "fontweight": "bold"},
    vmax= 1.6,
    vmin= 0.3
)

cbar = plt.gcf().axes[-1]
cbar.tick_params(labelsize=16)
cbar.set_ylabel("RMSE", fontsize=16, fontweight="bold")

plt.title("Test RMSE Heatmap for Bw: Glacier × Model (1950-2023)", fontsize=18, fontweight="bold", pad=15)
plt.xlabel("Model (Regressor + Selector)", fontsize=16, fontweight="bold", labelpad=10)
plt.ylabel("Glacier", fontsize=16, fontweight="bold", labelpad=10)

plt.xticks(rotation=45, ha='right', fontsize=18)
plt.yticks(rotation=45, fontsize=18)

plt.tight_layout()
plt.subplots_adjust(left=0.07, right=0.95, top=0.93, bottom=0.15)
#plt.savefig(r"C:\Users\danis\Desktop\Danish\Py-Plots\08- Bw Model Routine\Complete\heatmap_rmse_bw_complete.png", dpi=800, bbox_inches='tight')
plt.show()

# %%
# Load your updated CSV
#df = pd.read_csv(metrics_path)
df= results_df

# Define custom colors for Selector methods
colors = {
    "Recursive": "#ca0020",   # red
    "Sequential": "#0571b0",  # blue
    "TreeBased": "#fdb863"    # orange-yellow
}

gridline_color = "#d3d3d3"
variables = ["Bw"]

for var in variables:
    fig, ax = plt.subplots(figsize=(15, 8))
    sns.boxplot(data=df[df["Variable"] == var], x="Regressor", y="R2", hue="Selector", palette=colors, ax=ax)

    ax.set_title(f"Test R² Scores for {var}", fontsize=16, fontweight="bold")
    ax.set_ylabel("Test R²", fontsize=14, fontweight="bold")
    ax.set_xlabel("Regressor", fontsize=14, fontweight="bold")
    ax.grid(True, linestyle="--", color=gridline_color)
    ax.legend(title="Selector", title_fontsize=14, fontsize=12)
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

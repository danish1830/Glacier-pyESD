# %% [markdown]
# ## Historical CMIP6 Data

# %% [markdown]
# ### Downloading Historical data

# %%
import cdsapi

dataset = "projections-cmip6"
request = {
    "temporal_resolution": "monthly",
    "experiment": "historical",
    "variable": "surface_downwelling_shortwave_radiation",
    "model": "mpi_esm1_2_lr",
    "year": [
        "1950", "1951", "1952",
        "1953", "1954", "1955",
        "1956", "1957", "1958",
        "1959", "1960", "1961",
        "1962", "1963", "1964",
        "1965", "1966", "1967",
        "1968", "1969", "1970",
        "1971", "1972", "1973",
        "1974", "1975", "1976",
        "1977", "1978", "1979",
        "1980", "1981", "1982",
        "1983", "1984", "1985",
        "1986", "1987", "1988",
        "1989", "1990", "1991",
        "1992", "1993", "1994",
        "1995", "1996", "1997",
        "1998", "1999", "2000",
        "2001", "2002", "2003",
        "2004", "2005", "2006",
        "2007", "2008", "2009",
        "2010", "2011", "2012",
        "2013", "2014"
    ],
    #"month": ["05", "06", "07", "08", "09"],
    #"month": ["01", "02", "12"],
    "month": ["01", "02", "03", "04", "05", "06", "07", "08", "09", "10", "11", "12"],

}

client = cdsapi.Client()
client.retrieve(dataset, request).download()
# Out:
# 2025-06-17 16:54:57,330 INFO [2025-06-16T00:00:00] CC-BY licence to replace Licence to use Copernicus Products on 02 July 2025. More information available [here](https://forum.ecmwf.int/t/cc-by-licence-to-replace-licence-to-use-copernicus-products-on-02-july-2025/13464)
# 2025-06-17 16:54:57,333 INFO [2025-06-10T00:00:00] To improve our C3S service, we need to hear from you! Please complete this very short [survey](https://confluence.ecmwf.int/x/E7uBEQ/). Thank you.
# 2025-06-17 16:54:57,334 INFO [2024-09-26T00:00:00] Watch our [Forum](https://forum.ecmwf.int/) for Announcements, news and other discussed topics.
# 2025-06-17 16:54:57,960 INFO Request ID is ad5e9ad7-ff94-4dca-a7c6-b85b0630492b
# 2025-06-17 16:54:58,036 INFO status has been updated to accepted
# 2025-06-17 16:55:06,777 INFO status has been updated to running
# 2025-06-17 16:55:31,094 INFO status has been updated to successful
# 'bc07e081f4bee252d18a24c755a66190.zip'

# %%
import os
import xarray as xr
import pandas as pd

# %%
ds= xr.open_dataset(r"C:\Users\danis\Desktop\Danish\CMIP6 Data\pr_Amon_MPI-ESM1-2-LR_historical_r1i1p1f1_gn_19500116-20141216.nc")
print(ds._coord_names)
ds
# Out:
# {'lon', 'time', 'lat'}
# <xarray.Dataset> Size: 61MB
# Dimensions:    (time: 780, bnds: 2, lat: 96, lon: 192)
# Coordinates:
#   * time       (time) datetime64[ns] 6kB 1950-01-16T12:00:00 ... 2014-12-16T1...
#   * lat        (lat) float64 768B -88.57 -86.72 -84.86 ... 84.86 86.72 88.57
#   * lon        (lon) float64 2kB 0.0 1.875 3.75 5.625 ... 354.4 356.2 358.1
# Dimensions without coordinates: bnds
# Data variables:
#     time_bnds  (time, bnds) datetime64[ns] 12kB ...
#     lat_bnds   (time, lat, bnds) float64 1MB ...
#     lon_bnds   (time, lon, bnds) float64 2MB ...
#     pr         (time, lat, lon) float32 58MB ...
# Attributes: (12/47)
#     Conventions:            CF-1.7 CMIP-6.2
#     activity_id:            CMIP
#     branch_method:          standard
#     branch_time_in_child:   0.0
#     branch_time_in_parent:  0.0
#     contact:                cmip6-mpi-esm@dkrz.de
#     ...                     ...
#     title:                  MPI-ESM1-2-LR output prepared for CMIP6
# ...

# %% [markdown]
# ### Editing for Ba

# %%
# editing the files for Ba:

output_dir = r"C:\Users\danis\Desktop\Danish\CMIP6 Data\Fixed\Historical"
os.makedirs(output_dir, exist_ok=True)

# --- t2m (from tas) ---
ds = xr.open_dataset(r"C:\Users\danis\Desktop\Danish\CMIP6 Data\tas_Amon_MPI-ESM1-2-LR_historical_r1i1p1f1_gn_19500116-20141216.nc")
if "valid_time" in ds.coords:
    ds = ds.rename({"valid_time": "time"})
ds = ds.rename({"tas": "t2m"})
ds["time"] = ds["time"].values.astype("datetime64[M]")
ds["t2m"].to_netcdf(r"C:\Users\danis\Desktop\Danish\CMIP6 Data\Fixed\Historical\historical_t2m_fixed.nc")
print(f"Saved: {output_dir}")

# --- tp (from pr) ---
ds = xr.open_dataset(r"C:\Users\danis\Desktop\Danish\CMIP6 Data\pr_Amon_MPI-ESM1-2-LR_historical_r1i1p1f1_gn_19500116-20141216.nc")
if "valid_time" in ds.coords:
    ds = ds.rename({"valid_time": "time"})
ds = ds.rename({"pr": "tp"})
ds["time"] = ds["time"].values.astype("datetime64[M]")
ds["tp"].to_netcdf(r"C:\Users\danis\Desktop\Danish\CMIP6 Data\Fixed\Historical\historical_tp_fixed.nc")
print(f"Saved: {output_dir}")

# --- msl (from psl) ---
ds = xr.open_dataset(r"C:\Users\danis\Desktop\Danish\CMIP6 Data\psl_Amon_MPI-ESM1-2-LR_historical_r1i1p1f1_gn_19500116-20141216.nc")
if "valid_time" in ds.coords:
    ds = ds.rename({"valid_time": "time"})
ds = ds.rename({"psl": "msl"})
ds["time"] = ds["time"].values.astype("datetime64[M]")
ds["msl"].to_netcdf(r"C:\Users\danis\Desktop\Danish\CMIP6 Data\Fixed\Historical\historical_msl_fixed.nc")
print(f"Saved: {output_dir}")

# --- u10 (from uas) ---
ds = xr.open_dataset(r"C:\Users\danis\Desktop\Danish\CMIP6 Data\uas_Amon_MPI-ESM1-2-LR_historical_r1i1p1f1_gn_19500116-20141216.nc")
if "valid_time" in ds.coords:
    ds = ds.rename({"valid_time": "time"})
ds = ds.rename({"uas": "u10"})
ds["time"] = ds["time"].values.astype("datetime64[M]")
ds["u10"].to_netcdf(r"C:\Users\danis\Desktop\Danish\CMIP6 Data\Fixed\Historical\historical_u10_fixed.nc")
print(f"Saved: {output_dir}")

# --- v10 (from vas) ---
ds = xr.open_dataset(r"C:\Users\danis\Desktop\Danish\CMIP6 Data\vas_Amon_MPI-ESM1-2-LR_historical_r1i1p1f1_gn_19500116-20141216.nc")
if "valid_time" in ds.coords:
    ds = ds.rename({"valid_time": "time"})
ds = ds.rename({"vas": "v10"})
ds["time"] = ds["time"].values.astype("datetime64[M]")
ds["v10"].to_netcdf(r"C:\Users\danis\Desktop\Danish\CMIP6 Data\Fixed\Historical\historical_v10_fixed.nc")
print(f"Saved: {output_dir}")

# --- ssrd (from rsds) ---
ds = xr.open_dataset(r"C:\Users\danis\Desktop\Danish\CMIP6 Data\rsds_Amon_MPI-ESM1-2-LR_historical_r1i1p1f1_gn_19500116-20141216.nc")
if "valid_time" in ds.coords:
    ds = ds.rename({"valid_time": "time"})
ds = ds.rename({"rsds": "ssrd"})
ds["time"] = ds["time"].values.astype("datetime64[M]")
ds["ssrd"].to_netcdf(r"C:\Users\danis\Desktop\Danish\CMIP6 Data\Fixed\Historical\historical_ssrd_fixed.nc")
print(f"Saved: {output_dir}")
# Out:
# Saved: C:\Users\danis\Desktop\Danish\CMIP6 Data\Fixed\Historical
# Saved: C:\Users\danis\Desktop\Danish\CMIP6 Data\Fixed\Historical
# Saved: C:\Users\danis\Desktop\Danish\CMIP6 Data\Fixed\Historical
# Saved: C:\Users\danis\Desktop\Danish\CMIP6 Data\Fixed\Historical
# Saved: C:\Users\danis\Desktop\Danish\CMIP6 Data\Fixed\Historical
# Saved: C:\Users\danis\Desktop\Danish\CMIP6 Data\Fixed\Historical

# %% [markdown]
# ### Editing the files for Bw:

# %%
files= {
    "t2m": r"C:\Users\danis\Desktop\Danish\CMIP6 Data\Fixed\Historical\historical_t2m_fixed.nc",
    "tp": r"C:\Users\danis\Desktop\Danish\CMIP6 Data\Fixed\Historical\historical_tp_fixed.nc",
    "u10": r"C:\Users\danis\Desktop\Danish\CMIP6 Data\Fixed\Historical\historical_u10_fixed.nc",
    "v10": r"C:\Users\danis\Desktop\Danish\CMIP6 Data\Fixed\Historical\historical_v10_fixed.nc",
    "ssrd": r"C:\Users\danis\Desktop\Danish\CMIP6 Data\Fixed\Historical\historical_ssrd_fixed.nc",
}
output_dir = r"C:\Users\danis\Desktop\Danish\CMIP6 Data\Fixed\Historical\DJF_MEAN"
os.makedirs(output_dir, exist_ok=True)

# DJF mean function
def compute_djf_mean(da):
    # Sort time and keep only DJF months
    da = da.sortby("time")
    da= da.sel(time=da.time.dt.month.isin([12, 1, 2]))
    

    # Assign each month to the DJF year: Dec goes to next year
    djf_years = da.time.dt.year + (da.time.dt.month == 12).astype(int)
    da.coords["djf_year"] = ("time", djf_years.data)

    # Group by DJF year and average over time
    djf = da.groupby("djf_year").mean("time")

    # Rename time axis properly for PyESD (as datetime)
    djf["djf_year"] = pd.to_datetime(djf["djf_year"].values, format="%Y")
    djf = djf.rename(djf_year="time")

    return djf


# Process and save
for var, filepath in files.items():
    ds = xr.open_dataset(filepath)
    
    # Get the variable
    da = ds[var] if var in ds.data_vars else list(ds.data_vars.values())[0]
    
    # Compute DJF mean
    djf_mean = compute_djf_mean(da)
    djf_mean.name = var
    
    # Fix the time: convert integer years → datetime64 (e.g., 1950 → 1950-01-01)
    djf_mean['time'] = pd.to_datetime(djf_mean['time'].values, format="%Y")
    djf_mean = djf_mean.sel(time=~djf_mean.time.to_index().duplicated())

    # Save with correct format
    output_path = os.path.join(output_dir, f"DJF_MEAN_historical_{var}.nc")
    djf_mean.to_netcdf(output_path)
    
    print(f"Saved: {output_path}")
# Out:
# Saved: C:\Users\danis\Desktop\Danish\CMIP6 Data\Fixed\Historical\DJF_MEAN\DJF_MEAN_historical_t2m.nc
# Saved: C:\Users\danis\Desktop\Danish\CMIP6 Data\Fixed\Historical\DJF_MEAN\DJF_MEAN_historical_tp.nc
# Saved: C:\Users\danis\Desktop\Danish\CMIP6 Data\Fixed\Historical\DJF_MEAN\DJF_MEAN_historical_u10.nc
# Saved: C:\Users\danis\Desktop\Danish\CMIP6 Data\Fixed\Historical\DJF_MEAN\DJF_MEAN_historical_v10.nc
# Saved: C:\Users\danis\Desktop\Danish\CMIP6 Data\Fixed\Historical\DJF_MEAN\DJF_MEAN_historical_ssrd.nc

# %% [markdown]
# ### Editing for Bs

# %%
files= {
    "t2m": r"C:\Users\danis\Desktop\Danish\CMIP6 Data\Fixed\Historical\historical_t2m_fixed.nc",
    "tp": r"C:\Users\danis\Desktop\Danish\CMIP6 Data\Fixed\Historical\historical_tp_fixed.nc",
    "u10": r"C:\Users\danis\Desktop\Danish\CMIP6 Data\Fixed\Historical\historical_u10_fixed.nc",
    "v10": r"C:\Users\danis\Desktop\Danish\CMIP6 Data\Fixed\Historical\historical_v10_fixed.nc",
    "ssrd": r"C:\Users\danis\Desktop\Danish\CMIP6 Data\Fixed\Historical\historical_ssrd_fixed.nc",
}
output_dir = r"C:\Users\danis\Desktop\Danish\CMIP6 Data\Fixed\Historical\MJJAS_MEAN"
os.makedirs(output_dir, exist_ok=True)


# MJJAS mean function
def compute_mjjas_mean(da):
    # Sort time and keep only MJJAS months
    da = da.sortby("time")
    da = da.sel(time=da.time.dt.month.isin([5, 6, 7, 8, 9]))

    mjjas_year= da.time.dt.year
    da.coords["mjjas_year"] = ("time", mjjas_year.data)

    # Group by DJF year and average over time
    mjjas = da.groupby("mjjas_year").mean("time")

    # Rename time axis properly for PyESD (as datetime)
    mjjas["mjjas_year"] = pd.to_datetime(mjjas["mjjas_year"].values, format="%Y")
    mjjas = mjjas.rename(mjjas_year="time")

    return mjjas


# Process and save
for var, filepath in files.items():
    ds = xr.open_dataset(filepath)
    
    # Get the variable
    da = ds[var] if var in ds.data_vars else list(ds.data_vars.values())[0]
    
    # Compute DJF mean
    mjjas_mean = compute_mjjas_mean(da)
    mjjas_mean.name = var
    
    # Fix the time: convert integer years → datetime64 (e.g., 1950 → 1950-01-01)
    mjjas_mean['time'] = pd.to_datetime(mjjas_mean['time'].values, format="%Y")
    mjjas_mean = mjjas_mean.sel(time=~mjjas_mean.time.to_index().duplicated())

    # Save with correct format
    output_path = os.path.join(output_dir, f"MJJAS_MEAN_historical_{var}.nc")
    mjjas_mean.to_netcdf(output_path)
    
    print(f"Saved: {output_path}")
# Out:
# Saved: C:\Users\danis\Desktop\Danish\CMIP6 Data\Fixed\Historical\MJJAS_MEAN\MJJAS_MEAN_historical_t2m.nc
# Saved: C:\Users\danis\Desktop\Danish\CMIP6 Data\Fixed\Historical\MJJAS_MEAN\MJJAS_MEAN_historical_tp.nc
# Saved: C:\Users\danis\Desktop\Danish\CMIP6 Data\Fixed\Historical\MJJAS_MEAN\MJJAS_MEAN_historical_u10.nc
# Saved: C:\Users\danis\Desktop\Danish\CMIP6 Data\Fixed\Historical\MJJAS_MEAN\MJJAS_MEAN_historical_v10.nc
# Saved: C:\Users\danis\Desktop\Danish\CMIP6 Data\Fixed\Historical\MJJAS_MEAN\MJJAS_MEAN_historical_ssrd.nc

# %% [markdown]
# ## SSP Data

# %% [markdown]
# ### Downloading SSP1 2.6, SSP2 4.5, and SSP5 8.5 datasets for each variable

# %%
import cdsapi

dataset = "projections-cmip6"
request = {
    "temporal_resolution": "monthly",
    "experiment": "ssp5_8_5",
    "variable": "surface_downwelling_shortwave_radiation",
    "model": "mpi_esm1_2_lr",
    "year": [
        "2015", "2016", "2017",
        "2018", "2019", "2020",
        "2021", "2022", "2023",
        "2024", "2025", "2026",
        "2027", "2028", "2029",
        "2030", "2031", "2032",
        "2033", "2034", "2035",
        "2036", "2037", "2038",
        "2039", "2040", "2041",
        "2042", "2043", "2044",
        "2045", "2046", "2047",
        "2048", "2049", "2050",
        "2051", "2052", "2053",
        "2054", "2055", "2056",
        "2057", "2058", "2059",
        "2060", "2061", "2062",
        "2063", "2064", "2065",
        "2066", "2067", "2068",
        "2069", "2070", "2071",
        "2072", "2073", "2074",
        "2075", "2076", "2077",
        "2078", "2079", "2080",
        "2081", "2082", "2083",
        "2084", "2085", "2086",
        "2087", "2088", "2089",
        "2090", "2091", "2092",
        "2093", "2094", "2095",
        "2096", "2097", "2098",
        "2099", "2100"
    ],
    "month": [
        "01", "02", "03",
        "04", "05", "06",
        "07", "08", "09",
        "10", "11", "12"
    ]
}

client = cdsapi.Client()
client.retrieve(dataset, request).download()
# Out:
# 2025-06-18 13:55:32,964 INFO [2025-06-16T00:00:00] CC-BY licence to replace Licence to use Copernicus Products on 02 July 2025. More information available [here](https://forum.ecmwf.int/t/cc-by-licence-to-replace-licence-to-use-copernicus-products-on-02-july-2025/13464)
# 2025-06-18 13:55:32,964 INFO [2025-06-10T00:00:00] To improve our C3S service, we need to hear from you! Please complete this very short [survey](https://confluence.ecmwf.int/x/E7uBEQ/). Thank you.
# 2025-06-18 13:55:32,965 INFO [2024-09-26T00:00:00] Watch our [Forum](https://forum.ecmwf.int/) for Announcements, news and other discussed topics.
# 2025-06-18 13:55:33,532 INFO Request ID is 80ef8baf-2356-45d6-8b23-72f292c9d9af
# 2025-06-18 13:55:33,624 INFO status has been updated to accepted
# 2025-06-18 13:55:55,294 INFO status has been updated to successful
# 'a4318b6ce60e5c263046c78d2212bce2.zip'

# %% [markdown]
# ### Editing for Ba

# %%
# editing the files for Ba:

output_dir = r"C:\Users\danis\Desktop\Danish\CMIP6 Data\Fixed\SSP\85"
os.makedirs(output_dir, exist_ok=True)

# --- t2m (from tas) ---
ds = xr.open_dataset(r"C:\Users\danis\Desktop\Danish\CMIP6 Data\SSP\85\tas_Amon_MPI-ESM1-2-LR_ssp585_r1i1p1f1_gn_20150116-21001216.nc")
if "valid_time" in ds.coords:
    ds = ds.rename({"valid_time": "time"})
ds = ds.rename({"tas": "t2m"})
ds["time"] = ds["time"].values.astype("datetime64[M]")
ds["t2m"].to_netcdf(r"C:\Users\danis\Desktop\Danish\CMIP6 Data\Fixed\SSP\85\ssp585_t2m_fixed.nc")
print(f"Saved: {output_dir}")

# --- tp (from pr) ---
ds = xr.open_dataset(r"C:\Users\danis\Desktop\Danish\CMIP6 Data\SSP\85\pr_Amon_MPI-ESM1-2-LR_ssp585_r1i1p1f1_gn_20150116-21001216.nc")
if "valid_time" in ds.coords:
    ds = ds.rename({"valid_time": "time"})
ds = ds.rename({"pr": "tp"})
ds["time"] = ds["time"].values.astype("datetime64[M]")
ds["tp"].to_netcdf(r"C:\Users\danis\Desktop\Danish\CMIP6 Data\Fixed\SSP\85\ssp585_tp_fixed.nc")
print(f"Saved: {output_dir}")

# --- msl (from psl) ---
ds = xr.open_dataset(r"C:\Users\danis\Desktop\Danish\CMIP6 Data\SSP\85\psl_Amon_MPI-ESM1-2-LR_ssp585_r1i1p1f1_gn_20150116-21001216.nc")
if "valid_time" in ds.coords:
    ds = ds.rename({"valid_time": "time"})
ds = ds.rename({"psl": "msl"})
ds["time"] = ds["time"].values.astype("datetime64[M]")
ds["msl"].to_netcdf(r"C:\Users\danis\Desktop\Danish\CMIP6 Data\Fixed\SSP\85\ssp585_msl_fixed.nc")
print(f"Saved: {output_dir}")

# --- u10 (from uas) ---
ds = xr.open_dataset(r"C:\Users\danis\Desktop\Danish\CMIP6 Data\SSP\85\uas_Amon_MPI-ESM1-2-LR_ssp585_r1i1p1f1_gn_20150116-21001216.nc")
if "valid_time" in ds.coords:
    ds = ds.rename({"valid_time": "time"})
ds = ds.rename({"uas": "u10"})
ds["time"] = ds["time"].values.astype("datetime64[M]")
ds["u10"].to_netcdf(r"C:\Users\danis\Desktop\Danish\CMIP6 Data\Fixed\SSP\85\ssp585_u10_fixed.nc")
print(f"Saved: {output_dir}")

# --- v10 (from vas) ---
ds = xr.open_dataset(r"C:\Users\danis\Desktop\Danish\CMIP6 Data\SSP\85\vas_Amon_MPI-ESM1-2-LR_ssp585_r1i1p1f1_gn_20150116-21001216.nc")
if "valid_time" in ds.coords:
    ds = ds.rename({"valid_time": "time"})
ds = ds.rename({"vas": "v10"})
ds["time"] = ds["time"].values.astype("datetime64[M]")
ds["v10"].to_netcdf(r"C:\Users\danis\Desktop\Danish\CMIP6 Data\Fixed\SSP\85\ssp585_v10_fixed.nc")
print(f"Saved: {output_dir}")

# --- ssrd (from rsds) ---
ds = xr.open_dataset(r"C:\Users\danis\Desktop\Danish\CMIP6 Data\SSP\85\rsds_Amon_MPI-ESM1-2-LR_ssp585_r1i1p1f1_gn_20150116-21001216.nc")
if "valid_time" in ds.coords:
    ds = ds.rename({"valid_time": "time"})
ds = ds.rename({"rsds": "ssrd"})
ds["time"] = ds["time"].values.astype("datetime64[M]")
ds["ssrd"].to_netcdf(r"C:\Users\danis\Desktop\Danish\CMIP6 Data\Fixed\SSP\85\ssp585_ssrd_fixed.nc")
print(f"Saved: {output_dir}")
# Out:
# Saved: C:\Users\danis\Desktop\Danish\CMIP6 Data\Fixed\SSP\85
# Saved: C:\Users\danis\Desktop\Danish\CMIP6 Data\Fixed\SSP\85
# Saved: C:\Users\danis\Desktop\Danish\CMIP6 Data\Fixed\SSP\85
# Saved: C:\Users\danis\Desktop\Danish\CMIP6 Data\Fixed\SSP\85
# Saved: C:\Users\danis\Desktop\Danish\CMIP6 Data\Fixed\SSP\85
# Saved: C:\Users\danis\Desktop\Danish\CMIP6 Data\Fixed\SSP\85

# %% [markdown]
# ### Editing for Bw

# %%
files= {
    "t2m": r"C:\Users\danis\Desktop\Danish\CMIP6 Data\Fixed\SSP\85\ssp585_t2m_fixed.nc",
    "tp": r"C:\Users\danis\Desktop\Danish\CMIP6 Data\Fixed\SSP\85\ssp585_tp_fixed.nc",
    "u10": r"C:\Users\danis\Desktop\Danish\CMIP6 Data\Fixed\SSP\85\ssp585_u10_fixed.nc",
    "v10": r"C:\Users\danis\Desktop\Danish\CMIP6 Data\Fixed\SSP\85\ssp585_v10_fixed.nc",
    "ssrd": r"C:\Users\danis\Desktop\Danish\CMIP6 Data\Fixed\SSP\85\ssp585_ssrd_fixed.nc",
}
output_dir = r"C:\Users\danis\Desktop\Danish\CMIP6 Data\Fixed\SSP\85\DJF_MEAN"
os.makedirs(output_dir, exist_ok=True)

# DJF mean function
def compute_djf_mean(da):
    # Sort time and keep only DJF months
    da = da.sortby("time")
    da= da.sel(time=da.time.dt.month.isin([12, 1, 2]))
    

    # Assign each month to the DJF year: Dec goes to next year
    djf_years = da.time.dt.year + (da.time.dt.month == 12).astype(int)
    da.coords["djf_year"] = ("time", djf_years.data)

    # Group by DJF year and average over time
    djf = da.groupby("djf_year").mean("time")

    # Rename time axis properly for PyESD (as datetime)
    djf["djf_year"] = pd.to_datetime(djf["djf_year"].values, format="%Y")
    djf = djf.rename(djf_year="time")

    return djf


# Process and save
for var, filepath in files.items():
    ds = xr.open_dataset(filepath)
    
    # Get the variable
    da = ds[var] if var in ds.data_vars else list(ds.data_vars.values())[0]
    
    # Compute DJF mean
    djf_mean = compute_djf_mean(da)
    djf_mean.name = var
    
    # Fix the time: convert integer years → datetime64 (e.g., 1950 → 1950-01-01)
    djf_mean['time'] = pd.to_datetime(djf_mean['time'].values, format="%Y")
    djf_mean = djf_mean.sel(time=~djf_mean.time.to_index().duplicated())

    # Save with correct format
    output_path = os.path.join(output_dir, f"DJF_MEAN_ssp585_{var}.nc")
    djf_mean.to_netcdf(output_path)
    
    print(f"Saved: {output_path}")
# Out:
# Saved: C:\Users\danis\Desktop\Danish\CMIP6 Data\Fixed\SSP\85\DJF_MEAN\DJF_MEAN_ssp585_t2m.nc
# Saved: C:\Users\danis\Desktop\Danish\CMIP6 Data\Fixed\SSP\85\DJF_MEAN\DJF_MEAN_ssp585_tp.nc
# Saved: C:\Users\danis\Desktop\Danish\CMIP6 Data\Fixed\SSP\85\DJF_MEAN\DJF_MEAN_ssp585_u10.nc
# Saved: C:\Users\danis\Desktop\Danish\CMIP6 Data\Fixed\SSP\85\DJF_MEAN\DJF_MEAN_ssp585_v10.nc
# Saved: C:\Users\danis\Desktop\Danish\CMIP6 Data\Fixed\SSP\85\DJF_MEAN\DJF_MEAN_ssp585_ssrd.nc

# %% [markdown]
# ### Editing for Bs

# %%
files= {
    "t2m": r"C:\Users\danis\Desktop\Danish\CMIP6 Data\Fixed\SSP\85\ssp585_t2m_fixed.nc",
    "tp": r"C:\Users\danis\Desktop\Danish\CMIP6 Data\Fixed\SSP\85\ssp585_tp_fixed.nc",
    "u10": r"C:\Users\danis\Desktop\Danish\CMIP6 Data\Fixed\SSP\85\ssp585_u10_fixed.nc",
    "v10": r"C:\Users\danis\Desktop\Danish\CMIP6 Data\Fixed\SSP\85\ssp585_v10_fixed.nc",
    "ssrd": r"C:\Users\danis\Desktop\Danish\CMIP6 Data\Fixed\SSP\85\ssp585_ssrd_fixed.nc",
}
output_dir = r"C:\Users\danis\Desktop\Danish\CMIP6 Data\Fixed\SSP\85\MJJAS_MEAN"
os.makedirs(output_dir, exist_ok=True)

# MJJAS mean function
def compute_mjjas_mean(da):
    # Sort time and keep only MJJAS months
    da = da.sortby("time")
    da = da.sel(time=da.time.dt.month.isin([5, 6, 7, 8, 9]))

    mjjas_year= da.time.dt.year
    da.coords["mjjas_year"] = ("time", mjjas_year.data)

    # Group by DJF year and average over time
    mjjas = da.groupby("mjjas_year").mean("time")

    # Rename time axis properly for PyESD (as datetime)
    mjjas["mjjas_year"] = pd.to_datetime(mjjas["mjjas_year"].values, format="%Y")
    mjjas = mjjas.rename(mjjas_year="time")

    return mjjas


# Process and save
for var, filepath in files.items():
    ds = xr.open_dataset(filepath)
    
    # Get the variable
    da = ds[var] if var in ds.data_vars else list(ds.data_vars.values())[0]
    
    # Compute DJF mean
    mjjas_mean = compute_mjjas_mean(da)
    mjjas_mean.name = var
    
    # Fix the time: convert integer years → datetime64 (e.g., 1950 → 1950-01-01)
    mjjas_mean['time'] = pd.to_datetime(mjjas_mean['time'].values, format="%Y")
    mjjas_mean = mjjas_mean.sel(time=~mjjas_mean.time.to_index().duplicated())

    # Save with correct format
    output_path = os.path.join(output_dir, f"MJJAS_MEAN_ssp585_{var}.nc")
    mjjas_mean.to_netcdf(output_path)
    
    print(f"Saved: {output_path}")
# Out:
# Saved: C:\Users\danis\Desktop\Danish\CMIP6 Data\Fixed\SSP\85\MJJAS_MEAN\MJJAS_MEAN_ssp585_t2m.nc
# Saved: C:\Users\danis\Desktop\Danish\CMIP6 Data\Fixed\SSP\85\MJJAS_MEAN\MJJAS_MEAN_ssp585_tp.nc
# Saved: C:\Users\danis\Desktop\Danish\CMIP6 Data\Fixed\SSP\85\MJJAS_MEAN\MJJAS_MEAN_ssp585_u10.nc
# Saved: C:\Users\danis\Desktop\Danish\CMIP6 Data\Fixed\SSP\85\MJJAS_MEAN\MJJAS_MEAN_ssp585_v10.nc
# Saved: C:\Users\danis\Desktop\Danish\CMIP6 Data\Fixed\SSP\85\MJJAS_MEAN\MJJAS_MEAN_ssp585_ssrd.nc
